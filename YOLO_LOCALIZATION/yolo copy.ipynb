# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from datasets import load_dataset
from glob import glob
import torch
from torch.utils.data import DataLoader, Dataset
import xarray as xr
from einops import rearrange
from tqdm.notebook import tqdm
from joblib import Parallel, delayed
from PIL import Image
from time import time

# punjab=load_dataset('Zeel/bk_punjab')

# %%
from ultralytics import YOLO
# Load a model
model = YOLO('yolov8m.pt')

# %%
model = YOLO('/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/albk_v2/YOLO_LOCALIZATION/runs/detect/train10/weights/best.pt')
# validation_results = model.val(data='config.yaml',
#                                imgsz=640,
#                                batch=16,
#                                conf=0.25,
#                                iou=0.60,
#                                device='0')

# %%
path="/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/*.png"
images=glob(path)
len(images)
# Out:
# 1811

# %%
model.predict(source=images[:200], conf=0.25,imgsz=1120,device='2', save_txt=True,save= False,save_conf=True,save_crop=True,verbose=False)
# Out:
# Results saved to runs/detect/predict3
# 199 labels saved to runs/detect/predict3/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 83,  72,  73],
#          [ 81,  67,  68],
#          [ 83,  72,  73],
#          ...,
#          [ 90,  89, 106],
#          [100, 104, 116],
#          [ 98,  96, 106]],
#
#         [[ 92,  76,  76],
#          [ 83,  72,  73],
#          [ 81,  67,  68],
#          ...,
#          [ 90,  89, 106],
#          [100, 100, 116],
#          [ 90,  89, 106]],
#
#         [[ 92,  76,  76],
#          [ 92,  76,  76],
#          [ 81,  66,  73],
#          ...,
#          [ 90,  89, 106],
#          [ 92,  96, 114],
#          [ 92,  96, 114]],
#
#         ...,
#
#         [[105,  98, 106],
#          [121, 122, 132],
#          [ 96,  84,  84],
#          ...,
#          [104, 104, 124],
#          [ 96,  96, 116],
#          [121, 122, 140]],
#
#         [[121, 122, 132],
#          [121, 122, 132],
#          [ 96,  84,  84],
#          ...,
#          [100,  96, 116],
#          [ 96,  96, 116],
#          [121, 122, 140]],
#
#         [[114, 112, 123],
#          [105,  98, 106],
#          [ 96,  84,  92],
#          ...,
#          [100,  96, 116],
#          [105,  99, 113],
#          [116, 116, 131]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.90,85.12.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 84,  73,  64],
#          [ 90,  77,  69],
#          [ 90,  77,  69],
#          ...,
#          [ 94,  89,  85],
#          [ 94,  89,  85],
#          [ 89,  84,  84]],
#
#         [[ 90,  77,  69],
#          [ 90,  77,  69],
#          [ 90,  77,  69],
#          ...,
#          [ 94,  89,  85],
#          [ 94,  89,  85],
#          [ 94,  89,  85]],
#
#         [[ 79,  70,  60],
#          [ 79,  70,  60],
#          [ 79,  70,  60],
#          ...,
#          [ 94,  90,  89],
#          [ 94,  89,  85],
#          [ 94,  89,  85]],
#
#         ...,
#
#         [[139, 142, 142],
#          [139, 142, 142],
#          [166, 163, 166],
#          ...,
#          [ 77,  70,  74],
#          [ 74,  69,  69],
#          [ 77,  70,  74]],
#
#         [[190, 186, 190],
#          [190, 186, 190],
#          [166, 163, 166],
#          ...,
#          [ 77,  70,  74],
#          [ 74,  69,  69],
#          [ 74,  69,  69]],
#
#         [[166, 163, 166],
#          [190, 186, 190],
#          [190, 186, 190],
#          ...,
#          [ 78,  74,  77],
#          [ 74,  69,  69],
#          [ 74,  69,  69]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.91,86.41.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[59, 74, 45],
#          [68, 76, 50],
#          [68, 76, 50],
#          ...,
#          [35, 35, 34],
#          [50, 57, 50],
#          [65, 66, 57]],
#
#         [[57, 68, 38],
#          [57, 68, 38],
#          [57, 72, 38],
#          ...,
#          [50, 57, 54],
#          [50, 57, 50],
#          [65, 66, 57]],
#
#         [[57, 68, 38],
#          [57, 68, 38],
#          [57, 68, 38],
#          ...,
#          [64, 68, 68],
#          [57, 64, 64],
#          [65, 66, 57]],
#
#         ...,
#
#         [[30, 24,  9],
#          [32, 25,  6],
#          [33, 28,  7],
#          ...,
#          [33, 25,  9],
#          [37, 29, 13],
#          [37, 29, 13]],
#
#         [[46, 46, 29],
#          [50, 50, 29],
#          [52, 52, 34],
#          ...,
#          [29, 22,  8],
#          [33, 26, 12],
#          [33, 26, 12]],
#
#         [[41, 41, 25],
#          [50, 50, 29],
#          [56, 58, 37],
#          ...,
#          [29, 21,  6],
#          [29, 21,  6],
#          [29, 21,  6]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.86,84.52.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 64,  64,  50],
#          [ 73,  74,  57],
#          [ 92,  88,  72],
#          ...,
#          [ 92, 100,  68],
#          [ 92, 100,  68],
#          [ 92, 100,  68]],
#
#         [[ 92,  88,  72],
#          [ 92,  88,  72],
#          [ 73,  74,  57],
#          ...,
#          [ 80,  89,  58],
#          [ 92, 100,  68],
#          [ 92, 100,  68]],
#
#         [[ 64,  64,  50],
#          [ 73,  74,  57],
#          [ 80,  83,  64],
#          ...,
#          [ 73,  82,  51],
#          [ 80,  89,  58],
#          [ 80,  89,  58]],
#
#         ...,
#
#         [[ 60,  35,  19],
#          [ 60,  35,  19],
#          [ 60,  35,  19],
#          ...,
#          [132, 140, 136],
#          [108, 115, 107],
#          [100, 107,  99]],
#
#         [[ 60,  35,  19],
#          [ 60,  35,  19],
#          [ 60,  35,  19],
#          ...,
#          [124, 132, 124],
#          [108, 115, 107],
#          [140, 148, 156]],
#
#         [[ 60,  35,  19],
#          [ 60,  35,  19],
#          [ 60,  35,  19],
#          ...,
#          [124, 132, 124],
#          [108, 116, 124],
#          [132, 140, 136]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/26.03,86.88.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 53,  57,  53],
#          [ 60,  65,  66],
#          [ 60,  65,  66],
#          ...,
#          [ 57,  58,  59],
#          [ 53,  53,  48],
#          [ 36,  18,  20]],
#
#         [[ 53,  53,  48],
#          [ 57,  58,  59],
#          [ 58,  66,  58],
#          ...,
#          [ 61,  57,  48],
#          [ 53,  53,  48],
#          [ 24,  20,  24]],
#
#         [[ 40,  40,  40],
#          [ 48,  48,  48],
#          [ 53,  53,  48],
#          ...,
#          [ 44,  44,  44],
#          [ 40,  40,  40],
#          [ 36,  18,  20]],
#
#         ...,
#
#         [[ 41,  34,  50],
#          [ 43,  41,  50],
#          [ 48,  43,  50],
#          ...,
#          [ 65,  61,  91],
#          [ 65,  61,  91],
#          [ 65,  61,  91]],
#
#         [[ 41,  34,  50],
#          [ 43,  41,  50],
#          [ 48,  43,  50],
#          ...,
#          [ 73,  69,  99],
#          [ 73,  69,  99],
#          [ 69,  65,  97]],
#
#         [[ 41,  34,  50],
#          [ 41,  34,  50],
#          [ 48,  43,  50],
#          ...,
#          [ 77,  75, 105],
#          [ 77,  75, 105],
#          [ 73,  69,  99]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.87,86.64.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 44,  36,  16],
#          [ 44,  32,   8],
#          [ 58,  58,  41],
#          ...,
#          [ 36,  28,  12],
#          [ 49,  41,  25],
#          [ 40,  32,  16]],
#
#         [[ 48,  40,  20],
#          [ 44,  36,  16],
#          [ 56,  48,  28],
#          ...,
#          [ 36,  24,   4],
#          [ 49,  41,  25],
#          [ 36,  24,   4]],
#
#         [[ 44,  32,   8],
#          [ 44,  32,   8],
#          [ 44,  36,  16],
#          ...,
#          [ 36,  24,   4],
#          [ 36,  28,  12],
#          [ 36,  28,  12]],
#
#         ...,
#
#         [[ 66,  81,  90],
#          [ 65,  76,  82],
#          [ 65,  76,  82],
#          ...,
#          [ 82,  98, 113],
#          [131, 147, 155],
#          [131, 147, 155]],
#
#         [[ 66,  81,  90],
#          [ 64,  76,  88],
#          [ 65,  76,  82],
#          ...,
#          [ 89, 106, 121],
#          [131, 147, 155],
#          [116, 139, 163]],
#
#         [[ 72,  80,  92],
#          [ 66,  81,  90],
#          [ 65,  76,  82],
#          ...,
#          [ 89, 106, 121],
#          [116, 135, 139],
#          [116, 135, 139]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.21,85.16.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 37,  42,  41],
#          [ 37,  42,  41],
#          [ 37,  42,  41],
#          ...,
#          [ 49,  57,  77],
#          [ 57,  69,  85],
#          [ 67,  76,  91]],
#
#         [[ 37,  42,  41],
#          [ 37,  42,  41],
#          [ 43,  45,  43],
#          ...,
#          [ 57,  69,  85],
#          [ 57,  69,  85],
#          [ 61,  73,  89]],
#
#         [[ 37,  42,  41],
#          [ 43,  45,  43],
#          [ 41,  45,  52],
#          ...,
#          [ 58,  66,  74],
#          [ 49,  57,  77],
#          [ 57,  69,  85]],
#
#         ...,
#
#         [[164, 171, 168],
#          [190, 184, 184],
#          [172, 180, 187],
#          ...,
#          [ 29,  31,  12],
#          [ 29,  31,  12],
#          [ 25,  24,  10]],
#
#         [[146, 164, 169],
#          [190, 184, 184],
#          [172, 180, 187],
#          ...,
#          [ 29,  31,  12],
#          [ 29,  31,  12],
#          [ 25,  24,  10]],
#
#         [[172, 180, 187],
#          [140, 156, 164],
#          [ 73,  80,  76],
#          ...,
#          [ 29,  31,  12],
#          [ 25,  24,  10],
#          [ 22,  22,   6]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.43,87.62.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 88,  68,  65],
#          [ 81,  57,  49],
#          [ 73,  50,  42],
#          ...,
#          [ 89,  74,  81],
#          [104,  96, 116],
#          [100,  96, 114]],
#
#         [[ 68,  44,  36],
#          [ 73,  50,  42],
#          [ 68,  44,  36],
#          ...,
#          [112, 100, 113],
#          [100,  92, 108],
#          [ 90,  80,  90]],
#
#         [[ 60,  32,  28],
#          [ 68,  44,  36],
#          [ 76,  52,  36],
#          ...,
#          [ 81,  66,  73],
#          [112, 100, 113],
#          [104,  92, 105]],
#
#         ...,
#
#         [[ 89,  74,  81],
#          [ 96,  76,  81],
#          [ 91,  80,  82],
#          ...,
#          [135, 147, 183],
#          [135, 147, 183],
#          [131, 139, 167]],
#
#         [[ 89,  74,  81],
#          [ 89,  74,  81],
#          [ 91,  80,  82],
#          ...,
#          [131, 139, 167],
#          [131, 139, 167],
#          [128, 131, 159]],
#
#         [[ 89,  74,  81],
#          [ 89,  74,  81],
#          [ 89,  73,  74],
#          ...,
#          [131, 139, 167],
#          [131, 139, 167],
#          [128, 131, 159]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.90,85.52.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 38,  20,  13],
#          [ 31,  31,  10],
#          [ 38,  38,  17],
#          ...,
#          [ 53,  60,  52],
#          [ 53,  60,  52],
#          [ 53,  60,  52]],
#
#         [[ 38,  20,  13],
#          [ 27,  28,  28],
#          [ 43,  44,  28],
#          ...,
#          [ 53,  60,  52],
#          [ 53,  60,  52],
#          [ 53,  60,  52]],
#
#         [[ 24,  20,   0],
#          [ 24,  20,   0],
#          [ 43,  44,  28],
#          ...,
#          [ 60,  68,  59],
#          [ 60,  68,  59],
#          [ 60,  68,  59]],
#
#         ...,
#
#         [[ 60,  68,  59],
#          [ 60,  68,  59],
#          [ 62,  62,  42],
#          ...,
#          [102, 118, 127],
#          [ 98, 110, 122],
#          [ 93, 107, 118]],
#
#         [[ 51,  50,  43],
#          [ 60,  68,  59],
#          [ 62,  62,  42],
#          ...,
#          [102, 114, 127],
#          [ 98, 110, 122],
#          [ 93, 107, 118]],
#
#         [[ 43,  44,  28],
#          [ 51,  50,  43],
#          [ 60,  68,  59],
#          ...,
#          [ 98, 110, 122],
#          [ 93, 107, 118],
#          [ 93, 107, 118]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.68,86.57.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 67,  67,  68],
#          [ 61,  61,  61],
#          [ 61,  61,  61],
#          ...,
#          [135, 149, 167],
#          [135, 149, 167],
#          [135, 149, 167]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 61,  61,  61],
#          ...,
#          [135, 149, 167],
#          [135, 149, 167],
#          [135, 149, 167]],
#
#         [[ 62,  59,  50],
#          [ 57,  53,  52],
#          [ 57,  53,  52],
#          ...,
#          [135, 149, 167],
#          [135, 149, 167],
#          [128, 145, 159]],
#
#         ...,
#
#         [[104, 119, 132],
#          [135, 149, 167],
#          [141, 163, 179],
#          ...,
#          [ 50,  48,  41],
#          [ 44,  41,  34],
#          [ 51,  44,  41]],
#
#         [[ 83,  98, 114],
#          [108, 122, 132],
#          [135, 141, 145],
#          ...,
#          [ 57,  53,  44],
#          [ 51,  44,  41],
#          [ 53,  49,  48]],
#
#         [[ 85,  96, 105],
#          [ 75,  83,  98],
#          [ 74,  82,  91],
#          ...,
#          [ 50,  48,  41],
#          [ 51,  44,  41],
#          [ 53,  49,  48]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.80,86.19.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 81, 105, 122],
#          [ 81, 105, 122],
#          [ 81, 105, 122],
#          ...,
#          [ 80,  96, 112],
#          [ 68,  80,  92],
#          [ 96, 114, 132]],
#
#         [[ 81, 105, 122],
#          [ 81, 105, 122],
#          [ 81, 105, 122],
#          ...,
#          [ 73,  89, 106],
#          [ 49,  65,  81],
#          [ 81, 105, 122]],
#
#         [[ 81, 105, 122],
#          [ 81, 105, 122],
#          [ 89, 106, 122],
#          ...,
#          [ 74,  88, 100],
#          [ 64,  84,  96],
#          [ 73,  89, 106]],
#
#         ...,
#
#         [[108, 124, 131],
#          [108, 124, 131],
#          [108, 124, 131],
#          ...,
#          [ 44,  36,  36],
#          [ 56,  60,  67],
#          [ 56,  60,  67]],
#
#         [[120, 128, 155],
#          [108, 124, 131],
#          [108, 124, 131],
#          ...,
#          [ 43,  44,  51],
#          [ 52,  52,  64],
#          [ 51,  52,  52]],
#
#         [[108, 131, 147],
#          [108, 124, 131],
#          [108, 124, 131],
#          ...,
#          [ 52,  52,  64],
#          [ 52,  52,  64],
#          [ 44,  36,  36]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.59,84.39.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 77,  82,  92],
#          [101, 109, 124],
#          [115, 127, 139],
#          ...,
#          [ 52,  46,  44],
#          [ 59,  55,  47],
#          [ 62,  58,  52]],
#
#         [[ 71,  77,  93],
#          [ 99, 107, 119],
#          [111, 123, 135],
#          ...,
#          [ 54,  50,  44],
#          [ 59,  51,  47],
#          [ 63,  55,  47]],
#
#         [[ 69,  71,  82],
#          [ 93,  99, 108],
#          [109, 118, 132],
#          ...,
#          [ 60,  54,  52],
#          [ 59,  55,  47],
#          [ 68,  60,  52]],
#
#         ...,
#
#         [[ 54,  50,  44],
#          [ 34,  30,  22],
#          [ 52,  46,  44],
#          ...,
#          [ 43,  34,  22],
#          [ 47,  39,  30],
#          [ 47,  39,  26]],
#
#         [[ 59,  55,  43],
#          [ 43,  39,  30],
#          [ 54,  50,  44],
#          ...,
#          [ 47,  39,  26],
#          [ 51,  39,  30],
#          [ 47,  39,  30]],
#
#         [[ 59,  55,  43],
#          [ 47,  43,  36],
#          [ 62,  58,  52],
#          ...,
#          [ 43,  39,  26],
#          [ 51,  43,  30],
#          [ 47,  39,  30]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.90,85.56.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 24,  25,  10],
#          [ 24,  25,  10],
#          [ 24,  25,  10],
#          ...,
#          [106, 122, 131],
#          [ 92, 108, 120],
#          [ 96, 112, 124]],
#
#         [[ 24,  25,  10],
#          [ 24,  25,  10],
#          [ 24,  25,  10],
#          ...,
#          [ 92, 104, 120],
#          [ 98, 114, 131],
#          [ 92, 108, 124]],
#
#         [[ 32,  34,  19],
#          [ 27,  32,  17],
#          [ 27,  32,  17],
#          ...,
#          [ 84, 100, 116],
#          [108, 124, 139],
#          [ 92, 108, 124]],
#
#         ...,
#
#         [[ 41,  42,  26],
#          [ 41,  42,  26],
#          [ 41,  42,  26],
#          ...,
#          [ 57,  67,  74],
#          [ 64,  72,  76],
#          [ 68,  80,  81]],
#
#         [[ 41,  42,  26],
#          [ 41,  42,  26],
#          [ 44,  48,  32],
#          ...,
#          [ 57,  67,  74],
#          [ 64,  72,  76],
#          [ 68,  80,  81]],
#
#         [[ 32,  34,  19],
#          [ 35,  41,  26],
#          [ 41,  42,  26],
#          ...,
#          [ 64,  72,  76],
#          [ 64,  74,  82],
#          [ 68,  80,  81]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.76,86.56.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 61,  60,  42],
#          [ 61,  60,  42],
#          [ 61,  60,  42],
#          ...,
#          [163, 182, 187],
#          [163, 180, 183],
#          [156, 175, 180]],
#
#         [[ 61,  60,  42],
#          [ 61,  60,  42],
#          [ 61,  60,  42],
#          ...,
#          [163, 182, 187],
#          [163, 182, 187],
#          [156, 175, 180]],
#
#         [[ 60,  58,  40],
#          [ 60,  58,  40],
#          [ 60,  58,  40],
#          ...,
#          [163, 182, 187],
#          [163, 182, 187],
#          [163, 182, 187]],
#
#         ...,
#
#         [[116, 127, 147],
#          [116, 127, 147],
#          [116, 127, 147],
#          ...,
#          [ 77,  77,  77],
#          [ 77,  77,  77],
#          [ 75,  71,  68]],
#
#         [[116, 131, 149],
#          [116, 131, 149],
#          [116, 127, 147],
#          ...,
#          [ 77,  77,  77],
#          [ 77,  77,  77],
#          [ 69,  68,  69]],
#
#         [[116, 131, 149],
#          [116, 131, 149],
#          [116, 131, 149],
#          ...,
#          [ 77,  77,  77],
#          [ 77,  77,  77],
#          [ 69,  68,  69]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.55,83.93.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[155, 179, 195],
#          [139, 155, 171],
#          [139, 155, 171],
#          ...,
#          [ 78,  87,  50],
#          [ 76,  83,  45],
#          [ 76,  83,  45]],
#
#         [[139, 155, 171],
#          [139, 155, 171],
#          [139, 155, 171],
#          ...,
#          [ 76,  83,  45],
#          [ 76,  83,  45],
#          [ 76,  83,  45]],
#
#         [[151, 167, 183],
#          [139, 155, 171],
#          [139, 155, 171],
#          ...,
#          [ 71,  83,  42],
#          [ 76,  83,  45],
#          [ 71,  83,  42]],
#
#         ...,
#
#         [[ 90,  94, 101],
#          [ 75,  77,  82],
#          [101, 108, 116],
#          ...,
#          [ 66,  61,  38],
#          [ 78,  69,  46],
#          [ 78,  69,  46]],
#
#         [[ 41,  42,  42],
#          [101, 108, 116],
#          [147, 163, 171],
#          ...,
#          [ 68,  70,  42],
#          [ 66,  61,  38],
#          [ 66,  61,  38]],
#
#         [[ 84,  86,  90],
#          [119, 131, 140],
#          [139, 155, 171],
#          ...,
#          [ 68,  70,  42],
#          [ 78,  69,  46],
#          [ 78,  69,  46]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.72,76.93.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 49,  51,  22],
#          [ 57,  59,  28],
#          [ 53,  57,  29],
#          ...,
#          [132, 144, 152],
#          [124, 136, 144],
#          [132, 144, 152]],
#
#         [[ 49,  44,  20],
#          [ 57,  59,  28],
#          [ 57,  59,  28],
#          ...,
#          [132, 144, 152],
#          [128, 140, 148],
#          [140, 156, 164]],
#
#         [[ 42,  41,  14],
#          [ 49,  51,  22],
#          [ 49,  51,  22],
#          ...,
#          [140, 156, 164],
#          [140, 156, 164],
#          [140, 156, 164]],
#
#         ...,
#
#         [[ 38,  33,  35],
#          [ 11,   5,   0],
#          [  0,   3,   0],
#          ...,
#          [ 49,  51,  13],
#          [ 42,  41,  14],
#          [ 49,  51,  13]],
#
#         [[ 92, 100, 107],
#          [  0,   3,   0],
#          [ 11,   5,   0],
#          ...,
#          [ 49,  51,  13],
#          [ 49,  51,  13],
#          [ 57,  59,  28]],
#
#         [[ 38,  33,  35],
#          [ 38,  33,  35],
#          [ 34,  27,  12],
#          ...,
#          [ 57,  59,  28],
#          [ 57,  59,  28],
#          [ 49,  51,  22]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.43,87.69.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 72,  68,  73],
#          [ 76,  72,  80],
#          [ 76,  72,  84],
#          ...,
#          [ 32,  20,   8],
#          [ 49,  34,  26],
#          [ 49,  34,  26]],
#
#         [[ 72,  68,  73],
#          [ 72,  68,  73],
#          [ 72,  68,  73],
#          ...,
#          [ 16,   4,   0],
#          [ 49,  34,  26],
#          [ 49,  34,  26]],
#
#         [[ 72,  68,  73],
#          [ 76,  72,  80],
#          [ 66,  64,  66],
#          ...,
#          [ 32,  20,   8],
#          [ 41,  25,  17],
#          [ 41,  25,  17]],
#
#         ...,
#
#         [[104, 113, 132],
#          [ 97, 105, 122],
#          [ 90, 104, 122],
#          ...,
#          [ 41,  25,  17],
#          [ 41,  25,  17],
#          [ 32,  20,   8]],
#
#         [[108, 124, 143],
#          [104, 113, 132],
#          [ 90, 104, 122],
#          ...,
#          [ 41,  25,  17],
#          [ 41,  25,  17],
#          [ 32,  20,   8]],
#
#         [[116, 139, 147],
#          [108, 131, 151],
#          [104, 120, 139],
#          ...,
#          [ 49,  34,  26],
#          [ 52,  40,  33],
#          [ 32,  20,   8]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.94,84.48.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 72,  57,  49],
#          [ 68,  56,  45],
#          [ 64,  51,  43],
#          ...,
#          [144, 159, 175],
#          [155, 180, 196],
#          [163, 187, 203]],
#
#         [[ 68,  56,  45],
#          [ 68,  56,  45],
#          [ 68,  56,  45],
#          ...,
#          [138, 154, 173],
#          [144, 159, 175],
#          [148, 164, 180]],
#
#         [[ 68,  56,  45],
#          [ 68,  56,  45],
#          [ 64,  56,  41],
#          ...,
#          [129, 145, 164],
#          [148, 164, 180],
#          [148, 164, 180]],
#
#         ...,
#
#         [[ 97,  90,  81],
#          [ 82,  80,  66],
#          [ 82,  80,  66],
#          ...,
#          [ 90,  90,  89],
#          [ 98,  96,  90],
#          [ 98,  97,  97]],
#
#         [[100, 108,  88],
#          [ 82,  80,  66],
#          [ 72,  68,  56],
#          ...,
#          [ 90,  89,  81],
#          [ 90,  90,  89],
#          [ 90,  90,  89]],
#
#         [[116, 108,  92],
#          [ 89,  82,  66],
#          [ 68,  64,  45],
#          ...,
#          [ 84,  88,  88],
#          [ 84,  88,  88],
#          [ 90,  90,  89]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.59,84.80.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[52, 64, 57],
#          [48, 60, 52],
#          [60, 68, 64],
#          ...,
#          [44, 56, 44],
#          [40, 52, 40],
#          [56, 64, 52]],
#
#         [[52, 64, 57],
#          [56, 64, 56],
#          [64, 72, 64],
#          ...,
#          [60, 68, 60],
#          [52, 64, 52],
#          [68, 76, 64]],
#
#         [[56, 68, 56],
#          [60, 72, 60],
#          [64, 76, 68],
#          ...,
#          [60, 72, 60],
#          [64, 76, 64],
#          [72, 82, 73]],
#
#         ...,
#
#         [[48, 56, 44],
#          [40, 52, 37],
#          [56, 64, 52],
#          ...,
#          [82, 96, 89],
#          [83, 97, 97],
#          [82, 96, 89]],
#
#         [[44, 56, 40],
#          [44, 56, 40],
#          [48, 56, 44],
#          ...,
#          [82, 96, 89],
#          [83, 97, 97],
#          [82, 96, 89]],
#
#         [[40, 52, 33],
#          [56, 64, 48],
#          [48, 56, 44],
#          ...,
#          [82, 96, 89],
#          [82, 96, 89],
#          [83, 97, 97]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.92,77.29.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 37,  36,  33],
#          [ 37,  42,  34],
#          [ 51,  58,  51],
#          ...,
#          [107, 117, 124],
#          [107, 117, 124],
#          [ 94, 107, 114]],
#
#         [[ 37,  42,  34],
#          [ 44,  51,  42],
#          [ 37,  42,  34],
#          ...,
#          [ 90, 102, 107],
#          [107, 117, 124],
#          [ 98, 107, 119]],
#
#         [[ 43,  45,  42],
#          [ 44,  51,  42],
#          [ 37,  42,  34],
#          ...,
#          [ 73,  83,  92],
#          [102, 111, 119],
#          [111, 119, 128]],
#
#         ...,
#
#         [[ 37,  33,  29],
#          [ 49,  50,  43],
#          [ 69,  65,  53],
#          ...,
#          [102, 114, 124],
#          [107, 117, 124],
#          [107, 117, 124]],
#
#         [[ 28,  26,  18],
#          [ 37,  36,  33],
#          [ 57,  58,  51],
#          ...,
#          [107, 117, 124],
#          [107, 117, 124],
#          [107, 117, 124]],
#
#         [[ 33,  33,  25],
#          [ 33,  29,  25],
#          [ 40,  41,  37],
#          ...,
#          [107, 117, 124],
#          [107, 117, 124],
#          [107, 117, 124]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.53,86.12.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 38,  38,  34],
#          [ 38,  38,  34],
#          [ 38,  34,  34],
#          ...,
#          [ 75,  84,  91],
#          [ 78,  83,  96],
#          [ 78,  83,  96]],
#
#         [[ 38,  38,  34],
#          [ 38,  34,  34],
#          [ 38,  38,  38],
#          ...,
#          [ 75,  84,  91],
#          [ 83,  87,  98],
#          [ 83,  87,  98]],
#
#         [[ 43,  42,  38],
#          [ 38,  38,  38],
#          [ 41,  38,  35],
#          ...,
#          [ 57,  61,  67],
#          [ 83,  87,  98],
#          [ 83,  90, 100]],
#
#         ...,
#
#         [[ 87,  96, 107],
#          [ 87,  96, 107],
#          [ 85,  96, 103],
#          ...,
#          [ 83,  90, 100],
#          [ 83,  96, 107],
#          [ 83,  87,  98]],
#
#         [[ 66,  78,  87],
#          [ 66,  74,  83],
#          [ 65,  74,  86],
#          ...,
#          [ 78,  86, 101],
#          [ 70,  83, 101],
#          [ 70,  78,  96]],
#
#         [[ 70,  78,  87],
#          [ 70,  78,  87],
#          [ 70,  78,  87],
#          ...,
#          [ 74,  87, 101],
#          [ 70,  83, 101],
#          [ 70,  83, 101]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.39,86.29.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[45, 34, 22],
#          [49, 37, 27],
#          [52, 41, 31],
#          ...,
#          [49, 51, 58],
#          [49, 51, 58],
#          [49, 51, 58]],
#
#         [[41, 31, 19],
#          [45, 37, 23],
#          [49, 41, 27],
#          ...,
#          [49, 51, 58],
#          [49, 51, 58],
#          [49, 51, 58]],
#
#         [[44, 35, 27],
#          [49, 37, 27],
#          [49, 41, 27],
#          ...,
#          [49, 51, 58],
#          [49, 51, 58],
#          [49, 51, 58]],
#
#         ...,
#
#         [[72, 59, 51],
#          [80, 68, 60],
#          [59, 44, 36],
#          ...,
#          [36, 27, 18],
#          [36, 27, 18],
#          [41, 31, 19]],
#
#         [[64, 45, 41],
#          [80, 68, 65],
#          [76, 65, 58],
#          ...,
#          [41, 31, 19],
#          [41, 31, 19],
#          [35, 27, 12]],
#
#         [[59, 44, 36],
#          [76, 65, 58],
#          [80, 68, 65],
#          ...,
#          [41, 31, 19],
#          [41, 31, 19],
#          [29, 20, 10]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.65,85.62.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 76,  88,  60],
#          [ 74,  82,  57],
#          [ 76,  88,  56],
#          ...,
#          [ 90, 100, 123],
#          [ 93, 106, 132],
#          [ 93, 106, 132]],
#
#         [[ 74,  90,  65],
#          [ 74,  82,  57],
#          [ 68,  80,  52],
#          ...,
#          [ 90, 100, 123],
#          [ 95, 107, 123],
#          [ 95, 107, 123]],
#
#         [[ 74,  90,  65],
#          [ 74,  82,  57],
#          [ 65,  73,  50],
#          ...,
#          [ 90, 100, 123],
#          [ 90, 100, 123],
#          [ 90, 100, 123]],
#
#         ...,
#
#         [[ 72,  82,  50],
#          [ 72,  82,  50],
#          [ 65,  74,  42],
#          ...,
#          [ 65,  73,  50],
#          [ 68,  80,  64],
#          [ 80,  98,  80]],
#
#         [[ 72,  76,  49],
#          [ 72,  82,  50],
#          [ 65,  74,  42],
#          ...,
#          [ 67,  82,  57],
#          [ 76,  98,  72],
#          [ 82, 107,  74]],
#
#         [[ 72,  76,  49],
#          [ 65,  74,  42],
#          [ 65,  74,  42],
#          ...,
#          [ 74,  90,  65],
#          [ 82, 107,  74],
#          [ 82, 107,  74]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.86,85.86.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 59,  67,  66],
#          [ 59,  67,  66],
#          [ 73,  83,  83],
#          ...,
#          [ 91, 106, 115],
#          [ 91, 106, 115],
#          [ 89, 100, 106]],
#
#         [[ 60,  73,  75],
#          [ 65,  75,  74],
#          [ 73,  83,  83],
#          ...,
#          [ 91, 106, 115],
#          [ 93, 105, 109],
#          [ 89, 100, 106]],
#
#         [[ 68,  82,  82],
#          [ 75,  90,  90],
#          [ 68,  82,  82],
#          ...,
#          [ 91, 106, 115],
#          [ 91, 106, 115],
#          [ 89, 100, 106]],
#
#         ...,
#
#         [[ 66,  76,  82],
#          [ 75,  90,  90],
#          [ 75,  90,  90],
#          ...,
#          [ 61,  50,  28],
#          [ 64,  50,  28],
#          [ 64,  50,  28]],
#
#         [[ 60,  73,  75],
#          [ 75,  90,  90],
#          [ 73,  85,  91],
#          ...,
#          [ 61,  50,  28],
#          [ 64,  50,  28],
#          [ 64,  50,  28]],
#
#         [[ 60,  73,  75],
#          [ 73,  83,  83],
#          [ 73,  85,  91],
#          ...,
#          [ 64,  50,  28],
#          [ 64,  50,  28],
#          [ 64,  50,  28]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.30,77.36.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[65, 73, 34],
#          [72, 81, 42],
#          [66, 81, 41],
#          ...,
#          [56, 58, 27],
#          [65, 67, 41],
#          [60, 64, 32]],
#
#         [[66, 81, 41],
#          [72, 81, 42],
#          [66, 81, 41],
#          ...,
#          [60, 64, 32],
#          [64, 66, 34],
#          [57, 59, 33]],
#
#         [[65, 73, 34],
#          [66, 81, 41],
#          [66, 80, 36],
#          ...,
#          [56, 58, 27],
#          [64, 66, 34],
#          [60, 64, 32]],
#
#         ...,
#
#         [[73, 89, 49],
#          [82, 89, 59],
#          [66, 73, 41],
#          ...,
#          [66, 73, 41],
#          [73, 76, 48],
#          [66, 73, 41]],
#
#         [[82, 89, 59],
#          [82, 89, 59],
#          [66, 81, 41],
#          ...,
#          [73, 76, 48],
#          [66, 73, 41],
#          [56, 64, 36]],
#
#         [[82, 89, 59],
#          [74, 89, 56],
#          [66, 73, 41],
#          ...,
#          [74, 81, 50],
#          [65, 67, 41],
#          [57, 59, 33]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.20,77.44.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 66,  63,  74],
#          [ 66,  63,  74],
#          [ 62,  63,  71],
#          ...,
#          [ 94, 105, 114],
#          [ 92,  97, 105],
#          [ 89,  93,  99]],
#
#         [[ 61,  62,  73],
#          [ 61,  62,  73],
#          [ 62,  63,  71],
#          ...,
#          [ 89,  97, 109],
#          [ 89,  93,  99],
#          [ 89,  97, 105]],
#
#         [[ 62,  63,  78],
#          [ 61,  62,  73],
#          [ 61,  62,  73],
#          ...,
#          [ 89,  97, 109],
#          [ 84,  92, 101],
#          [ 89,  97, 105]],
#
#         ...,
#
#         [[112, 128, 140],
#          [122, 138, 146],
#          [122, 138, 146],
#          ...,
#          [ 42,  42,  36],
#          [ 36,  40,  40],
#          [ 35,  35,  34]],
#
#         [[112, 128, 140],
#          [122, 138, 146],
#          [122, 138, 146],
#          ...,
#          [ 42,  42,  41],
#          [ 42,  42,  41],
#          [ 42,  42,  41]],
#
#         [[122, 138, 146],
#          [122, 138, 146],
#          [122, 138, 146],
#          ...,
#          [ 44,  50,  43],
#          [ 44,  50,  43],
#          [ 44,  50,  43]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.52,86.10.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[121, 132, 140],
#          [128, 144, 160],
#          [128, 144, 160],
#          ...,
#          [ 25,  28,  12],
#          [ 58,  67,  57],
#          [ 59,  67,  67]],
#
#         [[128, 144, 160],
#          [128, 144, 160],
#          [128, 144, 160],
#          ...,
#          [ 33,  42,  22],
#          [ 67,  75,  66],
#          [ 67,  75,  66]],
#
#         [[124, 136, 148],
#          [136, 152, 168],
#          [136, 152, 168],
#          ...,
#          [ 42,  52,  38],
#          [ 66,  74,  58],
#          [ 66,  74,  58]],
#
#         ...,
#
#         [[ 52,  59,  42],
#          [ 52,  59,  42],
#          [ 52,  59,  42],
#          ...,
#          [ 47,  52,  28],
#          [ 47,  52,  28],
#          [ 41,  52,  28]],
#
#         [[ 61,  65,  47],
#          [ 52,  57,  38],
#          [ 37,  41,  22],
#          ...,
#          [ 52,  57,  32],
#          [ 47,  52,  28],
#          [ 41,  47,  25]],
#
#         [[ 66,  75,  52],
#          [ 47,  52,  33],
#          [ 32,  37,  19],
#          ...,
#          [ 47,  52,  28],
#          [ 41,  47,  25],
#          [ 38,  46,  21]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.41,77.62.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[28, 34, 14],
#          [28, 34, 14],
#          [28, 34, 14],
#          ...,
#          [24, 33, 18],
#          [37, 42, 24],
#          [39, 45, 28]],
#
#         [[26, 28, 13],
#          [28, 34, 14],
#          [28, 34, 14],
#          ...,
#          [24, 33, 18],
#          [37, 42, 24],
#          [37, 45, 25]],
#
#         [[28, 34, 14],
#          [28, 34, 14],
#          [28, 34, 14],
#          ...,
#          [28, 38, 21],
#          [37, 42, 24],
#          [37, 42, 24]],
#
#         ...,
#
#         [[49, 49, 34],
#          [27, 21, 14],
#          [20, 14,  4],
#          ...,
#          [37, 45, 25],
#          [37, 42, 24],
#          [29, 40, 25]],
#
#         [[35, 26, 19],
#          [35, 26, 19],
#          [20, 14,  4],
#          ...,
#          [37, 42, 24],
#          [37, 42, 24],
#          [37, 42, 24]],
#
#         [[27, 21, 14],
#          [24, 24,  6],
#          [13, 12,  2],
#          ...,
#          [37, 42, 24],
#          [37, 42, 24],
#          [29, 40, 25]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.69,87.96.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 91, 108,  69],
#          [ 87, 107,  63],
#          [ 87, 107,  63],
#          ...,
#          [ 55,  67,  83],
#          [ 53,  61,  69],
#          [ 45,  52,  60]],
#
#         [[ 75,  95,  51],
#          [ 87,  99,  59],
#          [ 87,  99,  59],
#          ...,
#          [ 51,  59,  75],
#          [ 51,  59,  75],
#          [ 59,  67,  75]],
#
#         [[ 75,  95,  51],
#          [ 87,  99,  59],
#          [ 87,  99,  59],
#          ...,
#          [ 51,  59,  75],
#          [ 38,  45,  52],
#          [ 35,  38,  44]],
#
#         ...,
#
#         [[ 75,  82,  83],
#          [ 67,  76,  85],
#          [ 70,  78,  90],
#          ...,
#          [ 43,  51,  36],
#          [ 43,  51,  36],
#          [ 43,  51,  36]],
#
#         [[ 68,  76,  76],
#          [ 61,  69,  69],
#          [ 67,  76,  85],
#          ...,
#          [ 39,  47,  35],
#          [ 35,  43,  33],
#          [ 35,  43,  33]],
#
#         [[ 68,  76,  76],
#          [ 61,  69,  69],
#          [ 67,  76,  85],
#          ...,
#          [ 43,  51,  36],
#          [ 39,  47,  35],
#          [ 43,  51,  36]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.61,87.62.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 88, 103, 107],
#          [ 88, 103, 107],
#          [ 82,  92,  99],
#          ...,
#          [ 44,  53,  42],
#          [ 44,  53,  42],
#          [ 53,  62,  53]],
#
#         [[ 88, 103, 107],
#          [ 88, 103, 107],
#          [ 88, 103, 111],
#          ...,
#          [ 52,  59,  48],
#          [ 52,  62,  48],
#          [ 53,  62,  53]],
#
#         [[ 95, 107, 111],
#          [ 95, 107, 117],
#          [ 95, 107, 117],
#          ...,
#          [ 34,  44,  32],
#          [ 38,  44,  34],
#          [ 48,  54,  44]],
#
#         ...,
#
#         [[ 42,  53,  44],
#          [ 44,  53,  44],
#          [ 42,  52,  42],
#          ...,
#          [ 44,  53,  42],
#          [ 42,  52,  39],
#          [ 39,  48,  38]],
#
#         [[ 44,  53,  44],
#          [ 44,  53,  44],
#          [ 42,  52,  42],
#          ...,
#          [ 42,  52,  39],
#          [ 38,  48,  34],
#          [ 38,  48,  34]],
#
#         [[ 44,  53,  44],
#          [ 42,  53,  44],
#          [ 48,  59,  48],
#          ...,
#          [ 34,  44,  32],
#          [ 34,  44,  32],
#          [ 38,  48,  34]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.99,77.25.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 58,  60,  58],
#          [ 45,  49,  51],
#          [ 45,  49,  51],
#          ...,
#          [ 45,  41,  37],
#          [ 41,  37,  34],
#          [ 41,  37,  34]],
#
#         [[ 51,  58,  59],
#          [ 45,  49,  51],
#          [ 51,  58,  59],
#          ...,
#          [ 35,  34,  26],
#          [ 35,  34,  26],
#          [ 35,  34,  26]],
#
#         [[ 45,  49,  51],
#          [ 37,  40,  43],
#          [ 59,  66,  74],
#          ...,
#          [ 41,  37,  34],
#          [ 44,  45,  45],
#          [ 49,  45,  41]],
#
#         ...,
#
#         [[131, 140, 146],
#          [131, 140, 146],
#          [140, 147, 147],
#          ...,
#          [131, 140, 146],
#          [124, 136, 140],
#          [109, 116, 120]],
#
#         [[131, 140, 146],
#          [131, 140, 146],
#          [140, 147, 147],
#          ...,
#          [131, 140, 146],
#          [140, 147, 147],
#          [ 77,  83,  83]],
#
#         [[131, 140, 146],
#          [140, 147, 147],
#          [136, 156, 156],
#          ...,
#          [121, 128, 131],
#          [113, 120, 123],
#          [ 59,  65,  66]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.99,85.03.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
# ...
#          [ 54,  62,  50]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.95,77.25.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[149, 161, 180],
#          [149, 161, 180],
#          [149, 161, 180],
#          ...,
#          [ 56,  58,  52],
#          [ 56,  58,  52],
#          [ 60,  67,  56]],
#
#         [[149, 161, 180],
#          [149, 161, 180],
#          [149, 161, 180],
#          ...,
#          [ 52,  52,  41],
#          [ 49,  49,  41],
#          [ 52,  52,  41]],
#
#         [[149, 161, 180],
#          [149, 161, 180],
#          [149, 161, 180],
#          ...,
#          [ 56,  58,  43],
#          [ 56,  58,  43],
#          [ 56,  58,  43]],
#
#         ...,
#
#         [[ 52,  60,  49],
#          [ 56,  65,  56],
#          [ 56,  65,  56],
#          ...,
#          [ 46,  43,  38],
#          [ 38,  38,  31],
#          [ 38,  38,  31]],
#
#         [[ 52,  60,  49],
#          [ 60,  67,  56],
#          [ 60,  67,  56],
#          ...,
#          [ 46,  43,  38],
#          [ 38,  35,  31],
#          [ 38,  38,  31]],
#
#         [[ 52,  60,  52],
#          [ 60,  67,  60],
#          [ 60,  67,  56],
#          ...,
#          [ 41,  41,  35],
#          [ 38,  35,  31],
#          [ 38,  38,  31]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/26.13,87.86.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 74,  76,  67],
#          [ 75,  75,  75],
#          [ 75,  75,  75],
#          ...,
#          [113, 129, 145],
#          [113, 129, 145],
#          [100, 120, 136]],
#
#         [[ 75,  75,  75],
#          [ 83,  83,  74],
#          [ 83,  83,  74],
#          ...,
#          [106, 122, 137],
#          [113, 129, 145],
#          [106, 122, 137]],
#
#         [[ 67,  68,  68],
#          [ 75,  75,  75],
#          [ 75,  75,  75],
#          ...,
#          [100, 120, 136],
#          [113, 129, 145],
#          [113, 129, 145]],
#
#         ...,
#
#         [[ 67,  67,  47],
#          [ 63,  63,  43],
#          [ 50,  42,  27],
#          ...,
#          [ 76,  82,  83],
#          [ 75,  75,  75],
#          [ 76,  82,  83]],
#
#         [[ 63,  59,  39],
#          [ 58,  51,  35],
#          [ 46,  38,  19],
#          ...,
#          [ 75,  75,  75],
#          [ 83,  88,  90],
#          [ 81,  83,  84]],
#
#         [[ 63,  59,  39],
#          [ 50,  42,  27],
#          [ 38,  19,   8],
#          ...,
#          [ 76,  82,  83],
#          [ 81,  83,  84],
#          [ 81,  83,  84]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.19,85.11.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 60,  49,  41],
#          [ 58,  58,  48],
#          [ 50,  49,  42],
#          ...,
#          [131, 133, 141],
#          [131, 133, 141],
#          [127, 127, 135]],
#
#         [[ 50,  49,  42],
#          [ 52,  56,  44],
#          [ 40,  40,  28],
#          ...,
#          [127, 127, 135],
#          [131, 133, 141],
#          [122, 122, 131]],
#
#         [[ 58,  58,  48],
#          [ 58,  58,  48],
#          [ 43,  42,  34],
#          ...,
#          [122, 127, 135],
#          [131, 133, 141],
#          [122, 122, 131]],
#
#         ...,
#
#         [[ 25,  10,   8],
#          [ 25,  10,   8],
#          [ 25,  10,   8],
#          ...,
#          [ 76,  76,  76],
#          [ 76,  76,  76],
#          [ 76,  76,  76]],
#
#         [[ 33,  12,  12],
#          [ 33,  12,  12],
#          [ 33,  12,  12],
#          ...,
#          [ 76,  76,  76],
#          [ 76,  76,  76],
#          [ 80,  80,  80]],
#
#         [[ 33,  12,  12],
#          [ 33,  12,  12],
#          [ 33,  12,  12],
#          ...,
#          [ 84,  84,  84],
#          [ 84,  84,  84],
#          [ 84,  84,  84]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/26.10,85.26.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 81,  90, 113],
#          [ 81,  90, 113],
#          [108, 104,  96],
#          ...,
#          [ 96, 108, 136],
#          [ 96, 108, 136],
#          [ 96, 108, 136]],
#
#         [[ 90, 105, 130],
#          [ 90, 105, 130],
#          [ 90, 105, 130],
#          ...,
#          [ 96, 108, 136],
#          [ 90, 105, 130],
#          [ 90, 105, 130]],
#
#         [[ 88, 100, 124],
#          [ 90, 105, 130],
#          [ 90, 105, 130],
#          ...,
#          [ 90, 105, 130],
#          [ 88,  99, 128],
#          [ 80,  92, 120]],
#
#         ...,
#
#         [[ 36,  41,  61],
#          [ 33,  34,  44],
#          [ 33,  34,  44],
#          ...,
#          [ 51,  58,  66],
#          [ 51,  58,  66],
#          [ 51,  58,  66]],
#
#         [[ 36,  41,  61],
#          [ 17,  21,  43],
#          [ 17,  21,  43],
#          ...,
#          [ 46,  50,  57],
#          [ 46,  50,  57],
#          [ 46,  50,  57]],
#
#         [[ 36,  41,  61],
#          [ 17,  21,  43],
#          [ 33,  34,  44],
#          ...,
#          [ 46,  50,  57],
#          [ 47,  49,  50],
#          [ 47,  49,  50]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.58,84.74.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 98,  87,  79],
#          [105,  97,  91],
#          [110, 102,  98],
#          ...,
#          [115, 116, 123],
#          [122, 126, 134],
#          [122, 126, 134]],
#
#         [[ 91,  77,  69],
#          [ 98,  87,  79],
#          [102,  95,  87],
#          ...,
#          [115, 116, 123],
#          [126, 130, 138],
#          [130, 138, 147]],
#
#         [[ 84,  69,  61],
#          [ 87,  75,  67],
#          [ 92,  83,  77],
#          ...,
#          [107, 108, 115],
#          [114, 122, 130],
#          [122, 122, 130]],
#
#         ...,
#
#         [[ 60,  41,  33],
#          [ 60,  41,  33],
#          [ 60,  41,  33],
#          ...,
#          [102,  98, 102],
#          [ 99,  92,  97],
#          [115, 109, 115]],
#
#         [[ 60,  41,  33],
#          [ 60,  41,  33],
#          [ 68,  51,  42],
#          ...,
#          [ 98,  98, 101],
#          [ 92,  86,  90],
#          [ 98,  98, 101]],
#
#         [[ 68,  51,  42],
#          [ 68,  51,  42],
#          [ 75,  54,  48],
#          ...,
#          [ 99,  92,  97],
#          [102,  99, 105],
#          [ 99,  92,  97]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.60,86.53.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 36,  33,  33],
#          [ 32,  29,  26],
#          [ 28,  24,  21],
#          ...,
#          [ 45,  45,  37],
#          [ 37,  33,  29],
#          [ 53,  49,  49]],
#
#         [[ 32,  29,  26],
#          [ 28,  24,  21],
#          [ 28,  24,  21],
#          ...,
#          [ 45,  45,  37],
#          [ 45,  41,  37],
#          [ 48,  45,  43]],
#
#         [[ 32,  29,  26],
#          [ 28,  24,  21],
#          [ 28,  24,  21],
#          ...,
#          [ 45,  45,  37],
#          [ 53,  49,  45],
#          [ 48,  45,  43]],
#
#         ...,
#
#         [[ 85,  85,  81],
#          [ 89,  89,  85],
#          [ 93,  93,  93],
#          ...,
#          [ 77,  81,  89],
#          [ 93,  97, 105],
#          [ 93,  97, 105]],
#
#         [[ 84,  85,  85],
#          [ 89,  89,  85],
#          [ 85,  85,  81],
#          ...,
#          [ 97,  97, 108],
#          [ 93,  97, 105],
#          [112, 120, 128]],
#
#         [[ 69,  69,  69],
#          [ 69,  69,  69],
#          [ 65,  69,  65],
#          ...,
#          [ 98, 101, 112],
#          [ 89,  93, 101],
#          [ 93,  97, 105]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/26.13,84.69.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 76,  88,  88],
#          [ 84,  96,  97],
#          [ 99, 105, 106],
#          ...,
#          [ 65,  75,  65],
#          [ 48,  56,  52],
#          [ 52,  57,  58]],
#
#         [[ 97, 106, 114],
#          [ 97, 106, 114],
#          [ 82,  89,  90],
#          ...,
#          [ 65,  75,  65],
#          [ 65,  75,  65],
#          [ 52,  60,  52]],
#
#         [[ 84,  96,  97],
#          [ 90,  97,  98],
#          [ 90,  97,  98],
#          ...,
#          [ 72,  80,  68],
#          [ 65,  75,  65],
#          [ 60,  72,  58]],
#
#         ...,
#
#         [[163, 187, 195],
#          [163, 187, 195],
#          [145, 156, 164],
#          ...,
#          [ 31,  23,   9],
#          [ 23,   9,   5],
#          [ 49,  42,  27]],
#
#         [[148, 163, 171],
#          [163, 187, 195],
#          [156, 173, 179],
#          ...,
#          [ 38,  30,  17],
#          [ 18,  21,   0],
#          [ 44,  37,  21]],
#
#         [[132, 155, 163],
#          [167, 199, 207],
#          [167, 199, 207],
#          ...,
#          [ 44,  37,  21],
#          [ 18,  21,   0],
#          [ 31,  23,   9]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.91,77.30.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[125, 138, 155],
#          [141, 152, 159],
#          [121, 133, 148],
#          ...,
#          [ 32,  20,   4],
#          [ 23,   8,   0],
#          [ 43,  28,  12]],
#
#         [[121, 133, 148],
#          [125, 138, 155],
#          [125, 138, 155],
#          ...,
#          [ 32,  20,   4],
#          [ 43,  28,  12],
#          [ 54,  42,  38]],
#
#         [[115, 123, 138],
#          [115, 123, 138],
#          [125, 138, 155],
#          ...,
#          [ 32,  20,   4],
#          [ 43,  28,  12],
#          [ 54,  42,  38]],
#
#         ...,
#
#         [[ 69,  66,  36],
#          [ 43,  28,  12],
#          [109, 116,  66],
#          ...,
#          [ 98, 106, 122],
#          [ 98, 106, 122],
#          [ 98, 106, 122]],
#
#         [[ 75,  77,  35],
#          [102, 105,  66],
#          [ 91,  99,  53],
#          ...,
#          [ 98, 106, 122],
#          [106, 114, 130],
#          [106, 114, 130]],
#
#         [[ 75,  77,  35],
#          [ 82,  86,  37],
#          [ 77,  82,  34],
#          ...,
#          [ 99, 106, 113],
#          [ 98, 106, 122],
#          [105, 113, 123]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/28.84,76.86.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[ 91,  82,  82],
#          [100,  88,  84],
#          [ 96,  90,  90],
#          ...,
#          [108,  92,  76],
#          [108,  92,  76],
#          [108,  92,  76]],
#
#         [[104, 104, 104],
#          [116, 100,  92],
#          [100,  88,  84],
#          ...,
#          [108,  92,  76],
#          [100,  88,  84],
#          [116, 100,  92]],
#
#         [[143, 155, 167],
#          [139, 135, 151],
#          [131, 131, 138],
#          ...,
#          [ 98,  82,  66],
#          [ 90,  74,  65],
#          [108,  92,  76]],
#
#         ...,
#
#         [[ 84,  64,  36],
#          [ 89,  66,  41],
#          [ 89,  66,  41],
#          ...,
#          [143, 155, 167],
#          [143, 155, 167],
#          [143, 155, 167]],
#
#         [[ 89,  66,  41],
#          [ 89,  66,  41],
#          [ 89,  66,  41],
#          ...,
#          [128, 139, 167],
#          [143, 155, 167],
#          [143, 183, 207]],
#
#         [[ 89,  66,  41],
#          [ 96,  72,  44],
#          [ 89,  66,  41],
#          ...,
#          [120, 131, 151],
#          [120, 131, 151],
#          [128, 139, 167]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/24.87,85.28.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'zigzag', 1: 'fcbk'}
#  obb: None
#  orig_img: array([[[124, 140, 156],
#          [113, 132, 140],
#          [120, 132, 148],
#          ...,
#          [ 50,  43,  44],
#          [ 44,  42,  42],
#          [ 58,  51,  59]],
#
#         [[120, 132, 148],
#          [109, 120, 140],
#          [120, 132, 148],
#          ...,
#          [ 33,  25,  25],
#          [ 33,  25,  25],
#          [ 50,  43,  44]],
#
#         [[124, 140, 156],
#          [113, 132, 140],
#          [124, 140, 156],
#          ...,
#          [ 37,  25,   9],
#          [ 29,  13,   5],
#          [ 44,  37,  27]],
#
#         ...,
#
#         [[ 92, 100,  57],
#          [ 92, 100,  57],
#          [ 92, 100,  57],
#          ...,
#          [ 41,  37,  36],
#          [ 36,  33,  34],
#          [ 50,  43,  44]],
#
#         [[ 92, 100,  57],
#          [ 81,  85,  57],
#          [ 92, 100,  57],
#          ...,
#          [ 57,  51,  51],
#          [ 51,  49,  51],
#          [ 50,  43,  44]],
#
#         [[ 92, 100,  57],
#          [ 81,  85,  57],
#          [ 92, 100,  57],
#          ...,
#          [ 72,  69,  69],
#          [ 76,  69,  76],
#          [ 76,  69,  76]]], dtype=uint8)
#  orig_shape: (1120, 1120)
#  path: '/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_train_val_test_data/all_states/images/25.69,88.03.png'
#  probs: None
#  save_dir: 'runs/detect/predict3'
#  speed: {'preprocess': 10.92045783996582, 'inference': 5.839354991912842, 'postprocess': 2.5595366954803467}]

# %%
# path = "/home/rishabh.mondal/bkdb/statewise/RAJASTHAN"
# zarr_files = glob(os.path.join(path, "*.zarr"))
# print(len(zarr_files))

# class CustomDataset(Dataset):
#     def __init__(self, zarr_files):
#         self.zarr_files = zarr_files

#     def __len__(self):
#         return len(self.zarr_files)

#     def __getitem__(self, idx):
#         with xr.open_zarr(self.zarr_files[idx], consolidated=False) as ds:
#             pass
#         val = ds['data'].values
#         val = rearrange(val, 'row_lag col_lag row col channel -> (row_lag row) (col_lag col) channel')
#         return Image.fromarray(val)
#         # return torch.tensor(val) / 255.0
        

# # data = CustomDataset(zarr_files[:512])
# # loader = DataLoader(data, batch_size=64, shuffle=False, num_workers=8, collate_fn=lambda x: x)

# # for batch in tqdm(loader):
# #     model.predict(source=batch, conf=0.25,imgsz=1120,device='2', save_txt=True,save= False,save_conf=False,save_crop=False,verbose=False)

# def process(file):
#     with xr.open_zarr(file, consolidated=False) as ds:
#         pass
#     val = ds['data'].values
#     val = rearrange(val, 'row_lag col_lag row col channel -> (row_lag row) (col_lag col) channel')
#     return Image.fromarray(val)

# init = time()

# for i in tqdm(range(0, len(zarr_files), 256)):
#     tmp_files = zarr_files[i:i+256]
    
#     images = []
#     for i in range(0, len(tmp_files), 48):    
#         images.extend(Parallel(n_jobs=48)(delayed(process)(file) for file in tmp_files[i:i+48]))
#     print(time() - init)
#     print(len(images))
#     init = time()
#     model.predict(source=images, conf=0.25,imgsz=1120,device='2', save_txt=True,save= False,save_conf=True,save_crop=True,verbose=False)
#     print(time() - init)
# # results_pred = model.predict(source='/home/rishabh.mondal/Brick-Kilns-project/albk_rishabh/YOLO_DATA/negetiveclass', conf=0.25,imgsz=1120,device='2', save_txt=True,save= False,save_conf=False,save_crop=False,verbose=False)
# Out:
# 310115
#   0%|          | 0/1212 [00:00<?, ?it/s]
# 3.6195101737976074
# 256
# Results saved to runs/detect/predict2
# 10 labels saved to runs/detect/predict2/labels
# 9.997561931610107
# 12.097081422805786
# 256
# Results saved to runs/detect/predict2
# 18 labels saved to runs/detect/predict2/labels
# 6.373248815536499
# 8.779799699783325
# 256
# Results saved to runs/detect/predict2
# 28 labels saved to runs/detect/predict2/labels
# 6.648454904556274
# 8.91275405883789
# 256
# Results saved to runs/detect/predict2
# 31 labels saved to runs/detect/predict2/labels
# 5.591267347335815
# 7.76959753036499
# 256
# Results saved to runs/detect/predict2
# 35 labels saved to runs/detect/predict2/labels
# 8.019671201705933
# 10.23369574546814
# 256
# Results saved to runs/detect/predict2
# 44 labels saved to runs/detect/predict2/labels
# 5.843074798583984
# 8.127179622650146
# 256
# Results saved to runs/detect/predict2
# 46 labels saved to runs/detect/predict2/labels
# 6.783478021621704
# 9.024135828018188
# 256
# Results saved to runs/detect/predict2
# 48 labels saved to runs/detect/predict2/labels
# 5.40545392036438
# 7.861089706420898
# 256
# Results saved to runs/detect/predict2
# 55 labels saved to runs/detect/predict2/labels
# 5.552980899810791
# 7.967788219451904
# 256
# Results saved to runs/detect/predict2
# 59 labels saved to runs/detect/predict2/labels
# 5.3151445388793945
# 8.0245521068573
# 256
# Results saved to runs/detect/predict2
# 61 labels saved to runs/detect/predict2/labels
# 5.371545076370239
# 7.961385726928711
# 256
# Results saved to runs/detect/predict2
# 64 labels saved to runs/detect/predict2/labels
# 5.333867073059082
# 8.13664960861206
# 256
# Results saved to runs/detect/predict2
# 70 labels saved to runs/detect/predict2/labels
# 5.269729137420654
# 7.617926597595215
# 256
# Results saved to runs/detect/predict2
# 74 labels saved to runs/detect/predict2/labels
# 5.160144329071045
# 7.7857770919799805
# 256
# Results saved to runs/detect/predict2
# 77 labels saved to runs/detect/predict2/labels
# 5.184380054473877
# 7.577373743057251
# 256
# Results saved to runs/detect/predict2
# 81 labels saved to runs/detect/predict2/labels
# 5.395064353942871
# 8.005907535552979
# 256
# Results saved to runs/detect/predict2
# 84 labels saved to runs/detect/predict2/labels
# 5.096811771392822
# 7.20723032951355
# 256
# Results saved to runs/detect/predict2
# 90 labels saved to runs/detect/predict2/labels
# 5.749823331832886
# 7.901580572128296
# 256
# Results saved to runs/detect/predict2
# 94 labels saved to runs/detect/predict2/labels
# 9.223774433135986
# 11.57365894317627
# 256
# Results saved to runs/detect/predict2
# 101 labels saved to runs/detect/predict2/labels
# 5.221421957015991
# 7.451807498931885
# 256
# Results saved to runs/detect/predict2
# 107 labels saved to runs/detect/predict2/labels
# 5.17151403427124
# 7.308931350708008
# 256
# Results saved to runs/detect/predict2
# 110 labels saved to runs/detect/predict2/labels
# 5.217082262039185
# 7.500269174575806
# 256
# Results saved to runs/detect/predict2
# 118 labels saved to runs/detect/predict2/labels
# 5.497186183929443
# 8.087612390518188
# 256
# Results saved to runs/detect/predict2
# 127 labels saved to runs/detect/predict2/labels
# 5.443525791168213
# 7.790307521820068
# 256
# Results saved to runs/detect/predict2
# 131 labels saved to runs/detect/predict2/labels
# 5.3987603187561035
# 7.834686994552612
# 256
# Results saved to runs/detect/predict2
# 134 labels saved to runs/detect/predict2/labels
# 5.106002330780029
# 7.328986406326294
# 256
# Results saved to runs/detect/predict2
# 138 labels saved to runs/detect/predict2/labels
# 5.64942479133606
# 7.85097336769104
# 256
# Results saved to runs/detect/predict2
# 139 labels saved to runs/detect/predict2/labels
# 5.3460118770599365
# 7.966959714889526
# 256
# Results saved to runs/detect/predict2
# 143 labels saved to runs/detect/predict2/labels
# 6.807577848434448
# 8.943345069885254
# 256
# Results saved to runs/detect/predict2
# 147 labels saved to runs/detect/predict2/labels
# 5.167893409729004
# 7.573134899139404
# 256
# Results saved to runs/detect/predict2
# 148 labels saved to runs/detect/predict2/labels
# 5.0566911697387695
# 7.971055507659912
# 256
# Results saved to runs/detect/predict2
# 151 labels saved to runs/detect/predict2/labels
# 5.2256996631622314
# 7.531000852584839
# 256
# Results saved to runs/detect/predict2
# 157 labels saved to runs/detect/predict2/labels
# 5.178630590438843
# 7.368859052658081
# 256
# Results saved to runs/detect/predict2
# 160 labels saved to runs/detect/predict2/labels
# 5.14801287651062
# 7.338114261627197
# 256
# Results saved to runs/detect/predict2
# 163 labels saved to runs/detect/predict2/labels
# 5.197619915008545
# 7.281158924102783
# 256
# Results saved to runs/detect/predict2
# 163 labels saved to runs/detect/predict2/labels
# 5.321219205856323
# 7.427368402481079
# 256
# Results saved to runs/detect/predict2
# 165 labels saved to runs/detect/predict2/labels
# 5.274674892425537
# 7.722520351409912
# 256
# Results saved to runs/detect/predict2
# 169 labels saved to runs/detect/predict2/labels
# 5.278796672821045
# 7.3536951541900635
# 256
# Results saved to runs/detect/predict2
# 170 labels saved to runs/detect/predict2/labels
# 5.162198781967163
# 7.388276100158691
# 256
# Results saved to runs/detect/predict2
# 172 labels saved to runs/detect/predict2/labels
# 4.995177984237671
# 7.220589876174927
# 256
# Results saved to runs/detect/predict2
# 173 labels saved to runs/detect/predict2/labels
# 5.420864582061768
# 7.785024404525757
# 256
# Results saved to runs/detect/predict2
# 175 labels saved to runs/detect/predict2/labels
# 6.237811088562012
# 9.073211669921875
# 256
# Results saved to runs/detect/predict2
# 177 labels saved to runs/detect/predict2/labels
# 5.99557089805603
# 8.369359016418457
# 256
# Results saved to runs/detect/predict2
# 179 labels saved to runs/detect/predict2/labels
# 5.4808385372161865
# 7.708330392837524
# 256
# Results saved to runs/detect/predict2
# 182 labels saved to runs/detect/predict2/labels
# 5.510280132293701
# 8.148093700408936
# 256
# Results saved to runs/detect/predict2
# 185 labels saved to runs/detect/predict2/labels
# 6.0256288051605225
# 8.250685691833496
# 256
# Results saved to runs/detect/predict2
# 186 labels saved to runs/detect/predict2/labels
# 5.578969717025757
# 7.799437999725342
# 256
# Results saved to runs/detect/predict2
# 186 labels saved to runs/detect/predict2/labels
# 7.137814044952393
# 9.32371473312378
# 256
# Results saved to runs/detect/predict2
# 188 labels saved to runs/detect/predict2/labels
# 6.503506898880005
# 9.093285083770752
# 256
# Results saved to runs/detect/predict2
# 190 labels saved to runs/detect/predict2/labels
# 5.627179145812988
# 8.248432874679565
# 256
# Results saved to runs/detect/predict2
# 192 labels saved to runs/detect/predict2/labels
# 6.595693111419678
# 8.93807601928711
# 256
# Results saved to runs/detect/predict2
# 194 labels saved to runs/detect/predict2/labels
# 5.840672731399536
# 8.140495777130127
# 256
# Results saved to runs/detect/predict2
# 195 labels saved to runs/detect/predict2/labels
# 5.998246192932129
# 8.571702480316162
# 256
# Results saved to runs/detect/predict2
# 197 labels saved to runs/detect/predict2/labels
# 6.414262533187866
# 8.66661787033081
# 256
# Results saved to runs/detect/predict2
# 198 labels saved to runs/detect/predict2/labels
# 6.141901969909668
# 8.415854454040527
# 256
# Results saved to runs/detect/predict2
# 200 labels saved to runs/detect/predict2/labels
# 6.72513484954834
# 8.896398544311523
# 256
# Results saved to runs/detect/predict2
# 203 labels saved to runs/detect/predict2/labels
# 5.8470139503479
# 8.677289485931396
# 256
# Results saved to runs/detect/predict2
# 205 labels saved to runs/detect/predict2/labels
# 5.673142671585083
# 7.925064325332642
# 256
# Results saved to runs/detect/predict2
# 206 labels saved to runs/detect/predict2/labels
# 5.365355491638184
# 8.01336932182312
# 256
# Results saved to runs/detect/predict2
# 206 labels saved to runs/detect/predict2/labels
# 6.6553778648376465
# 9.311689615249634
# 256
# Results saved to runs/detect/predict2
# 206 labels saved to runs/detect/predict2/labels
# 5.503673076629639
# 8.125785827636719
# 256
# Results saved to runs/detect/predict2
# 207 labels saved to runs/detect/predict2/labels
# 5.6073362827301025
# 7.898086786270142
# 256
# Results saved to runs/detect/predict2
# 207 labels saved to runs/detect/predict2/labels
# 5.759392976760864
# 8.144123554229736
# 256
# Results saved to runs/detect/predict2
# 207 labels saved to runs/detect/predict2/labels
# 5.8107640743255615
# 8.004359722137451
# 256
# Results saved to runs/detect/predict2
# 209 labels saved to runs/detect/predict2/labels
# 6.324222803115845
# 9.193377494812012
# 256
# Results saved to runs/detect/predict2
# 211 labels saved to runs/detect/predict2/labels
# 6.347377300262451
# 8.548661231994629
# 256
# Results saved to runs/detect/predict2
# 212 labels saved to runs/detect/predict2/labels
# 6.865122079849243
# 9.086313724517822
# 256
# Results saved to runs/detect/predict2
# 214 labels saved to runs/detect/predict2/labels
# 5.797268390655518
# 8.1378915309906
# 256
# Results saved to runs/detect/predict2
# 214 labels saved to runs/detect/predict2/labels
# 6.350353240966797
# 8.581875085830688
# 256
# Results saved to runs/detect/predict2
# 218 labels saved to runs/detect/predict2/labels
# 5.803093433380127
# 8.144960165023804
# 256
# Results saved to runs/detect/predict2
# 220 labels saved to runs/detect/predict2/labels
# 7.625121116638184
# 9.807588577270508
# 256
# Results saved to runs/detect/predict2
# 222 labels saved to runs/detect/predict2/labels
# 6.532418727874756
# 8.791831970214844
# 256
# Results saved to runs/detect/predict2
# 222 labels saved to runs/detect/predict2/labels
# 6.498034238815308
# 9.098199367523193
# 256
# Results saved to runs/detect/predict2
# 222 labels saved to runs/detect/predict2/labels
# 6.401193857192993
# 8.5901780128479
# 256
# Results saved to runs/detect/predict2
# 222 labels saved to runs/detect/predict2/labels
# 5.408367395401001
# 7.914731025695801
# 256
# Results saved to runs/detect/predict2
# 223 labels saved to runs/detect/predict2/labels
# 5.308131694793701
# 7.958784818649292
# 256
# Results saved to runs/detect/predict2
# 224 labels saved to runs/detect/predict2/labels
# 5.352116346359253
# 7.532931566238403
# 256
# Results saved to runs/detect/predict2
# 225 labels saved to runs/detect/predict2/labels
# 5.404064416885376
# 7.8843889236450195
# 256
# Results saved to runs/detect/predict2
# 226 labels saved to runs/detect/predict2/labels
# 5.375816345214844
# 7.561239719390869
# 256
# Results saved to runs/detect/predict2
# 226 labels saved to runs/detect/predict2/labels
# 5.39586877822876
# 7.686470985412598
# 256
# Results saved to runs/detect/predict2
# 226 labels saved to runs/detect/predict2/labels
# 5.243042945861816
# 7.504470586776733
# 256
# Results saved to runs/detect/predict2
# 226 labels saved to runs/detect/predict2/labels
# 5.490528106689453
# 7.787944316864014
# 256
# Results saved to runs/detect/predict2
# 228 labels saved to runs/detect/predict2/labels
# 5.262435674667358
# 7.740709543228149
# 256
# Results saved to runs/detect/predict2
# 228 labels saved to runs/detect/predict2/labels
# 5.741966247558594
# 7.948523044586182
# 256
# Results saved to runs/detect/predict2
# 228 labels saved to runs/detect/predict2/labels
# 5.5519514083862305
# 8.034289360046387
# 256
# Results saved to runs/detect/predict2
# 228 labels saved to runs/detect/predict2/labels
# 5.693692445755005
# 7.891824245452881
# 256
# Results saved to runs/detect/predict2
# 229 labels saved to runs/detect/predict2/labels
# 5.371258735656738
# 7.581908226013184
# 256
# Results saved to runs/detect/predict2
# 229 labels saved to runs/detect/predict2/labels
# 5.405851125717163
# 7.854926824569702
# 256
# Results saved to runs/detect/predict2
# 229 labels saved to runs/detect/predict2/labels
# 5.443260908126831
# 7.644521236419678
# 256
# Results saved to runs/detect/predict2
# 230 labels saved to runs/detect/predict2/labels
# 6.147052764892578
# 8.740624904632568
# 256
# Results saved to runs/detect/predict2
# 232 labels saved to runs/detect/predict2/labels
# 6.81317925453186
# 9.030442714691162
# 256
# Results saved to runs/detect/predict2
# 235 labels saved to runs/detect/predict2/labels
# 5.396220922470093
# 7.782771587371826
# 256
# Results saved to runs/detect/predict2
# 235 labels saved to runs/detect/predict2/labels
# 6.62421989440918
# 8.871114015579224
# 256
# Results saved to runs/detect/predict2
# 235 labels saved to runs/detect/predict2/labels
# 5.726709842681885
# 8.179885625839233
# 256
# Results saved to runs/detect/predict2
# 236 labels saved to runs/detect/predict2/labels
# 5.939870595932007
# 8.087671756744385
# 256
# Results saved to runs/detect/predict2
# 236 labels saved to runs/detect/predict2/labels
# 5.757452011108398
# 8.15480089187622
# 256
# Results saved to runs/detect/predict2
# 237 labels saved to runs/detect/predict2/labels
# 5.787289619445801
# 7.972522020339966
# 256
# Results saved to runs/detect/predict2
# 237 labels saved to runs/detect/predict2/labels
# 5.631983041763306
# 7.926548480987549
# 256
# Results saved to runs/detect/predict2
# 238 labels saved to runs/detect/predict2/labels
# 5.350711107254028
# 8.071320056915283
# 256
# Results saved to runs/detect/predict2
# 238 labels saved to runs/detect/predict2/labels
# 7.312028408050537
# 9.647141456604004
# 256
# Results saved to runs/detect/predict2
# 238 labels saved to runs/detect/predict2/labels
# 5.944178819656372
# 8.278326511383057
# 256
# Results saved to runs/detect/predict2
# 239 labels saved to runs/detect/predict2/labels
# 5.859725713729858
# 8.050169467926025
# 256
# Results saved to runs/detect/predict2
# 240 labels saved to runs/detect/predict2/labels
# 5.584177732467651
# 7.756220579147339
# 256
# Results saved to runs/detect/predict2
# 241 labels saved to runs/detect/predict2/labels
# 5.727946043014526
# 7.947148084640503
# 256
# Results saved to runs/detect/predict2
# 242 labels saved to runs/detect/predict2/labels
# 6.84135890007019
# 9.175317764282227
# 256
# Results saved to runs/detect/predict2
# 242 labels saved to runs/detect/predict2/labels
# 5.8060972690582275
# 8.507035493850708
# 256
# Results saved to runs/detect/predict2
# 244 labels saved to runs/detect/predict2/labels
# 5.398820161819458
# 7.73825478553772
# 256
# Results saved to runs/detect/predict2
# 244 labels saved to runs/detect/predict2/labels
# 6.16133189201355
# 8.855962038040161
# 256
# Results saved to runs/detect/predict2
# 244 labels saved to runs/detect/predict2/labels
# 6.343266010284424
# 8.636295557022095
# 256
# Results saved to runs/detect/predict2
# 244 labels saved to runs/detect/predict2/labels
# 5.822335243225098
# 8.261219501495361
# 256
# Results saved to runs/detect/predict2
# 245 labels saved to runs/detect/predict2/labels
# 6.455470323562622
# 8.692401647567749
# 256
# Results saved to runs/detect/predict2
# 245 labels saved to runs/detect/predict2/labels
# 6.287358999252319
# 8.482790231704712
# 256
# Results saved to runs/detect/predict2
# 245 labels saved to runs/detect/predict2/labels
# 6.023668527603149
# 8.25843071937561
# 256
# Results saved to runs/detect/predict2
# 246 labels saved to runs/detect/predict2/labels
# 6.019328355789185
# 8.1811203956604
# 256
# Results saved to runs/detect/predict2
# 246 labels saved to runs/detect/predict2/labels
# 5.792893409729004
# 7.9516942501068115
# 256
# Results saved to runs/detect/predict2
# 246 labels saved to runs/detect/predict2/labels
# 6.671546697616577
# 8.862816095352173
# 256
# Results saved to runs/detect/predict2
# 246 labels saved to runs/detect/predict2/labels
# 6.1312761306762695
# 8.51149845123291
# 256
# Results saved to runs/detect/predict2
# 246 labels saved to runs/detect/predict2/labels
# 6.885761976242065
# 9.480914115905762
# 256
# Results saved to runs/detect/predict2
# 247 labels saved to runs/detect/predict2/labels
# 5.870328903198242
# 8.262866735458374
# 256
# Results saved to runs/detect/predict2
# 247 labels saved to runs/detect/predict2/labels
# 6.459962844848633
# 8.952325344085693
# 256
# Results saved to runs/detect/predict2
# 247 labels saved to runs/detect/predict2/labels
# 5.717854022979736
# 7.910501718521118
# 256
# Results saved to runs/detect/predict2
# 247 labels saved to runs/detect/predict2/labels
# 6.448516607284546
# 8.627108335494995
# 256
# Results saved to runs/detect/predict2
# 247 labels saved to runs/detect/predict2/labels
# 10.703691959381104
# 13.371839761734009
# 256
# Results saved to runs/detect/predict2
# 248 labels saved to runs/detect/predict2/labels
# 6.938034534454346
# 9.655693531036377
# 256
# Results saved to runs/detect/predict2
# 248 labels saved to runs/detect/predict2/labels
# 6.763461112976074
# 9.046611785888672
# 256
# Results saved to runs/detect/predict2
# 248 labels saved to runs/detect/predict2/labels
# 6.012550592422485
# 8.578628063201904
# 256
# Results saved to runs/detect/predict2
# 248 labels saved to runs/detect/predict2/labels
# 6.583889961242676
# 8.86412501335144
# 256
# Results saved to runs/detect/predict2
# 248 labels saved to runs/detect/predict2/labels
# 5.800316333770752
# 8.114140510559082
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 7.35313081741333
# 9.711018800735474
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 6.964621067047119
# 9.755380630493164
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 5.655254602432251
# 7.960073709487915
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 6.148340463638306
# 8.326955795288086
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 6.792202949523926
# 8.883954524993896
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 6.87112021446228
# 8.970723390579224
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 5.7980101108551025
# 7.96863865852356
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 6.0394392013549805
# 8.153105974197388
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 5.788743734359741
# 8.143779754638672
# 256
# Results saved to runs/detect/predict2
# 249 labels saved to runs/detect/predict2/labels
# 7.01042366027832
# 9.496807336807251
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.6784443855285645
# 8.849783420562744
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.5943474769592285
# 7.741904020309448
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.364053964614868
# 7.506190776824951
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.739540338516235
# 8.192665338516235
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.456509351730347
# 8.682936191558838
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.171257734298706
# 7.297704458236694
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.231218099594116
# 7.627764463424683
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.322917938232422
# 7.464403867721558
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.625868320465088
# 8.077281951904297
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.497293472290039
# 7.66935396194458
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.153546094894409
# 8.484745025634766
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.884145498275757
# 8.014949560165405
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.960429430007935
# 9.164723634719849
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 5.619182109832764
# 7.767051935195923
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.032307386398315
# 8.405576944351196
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.151572942733765
# 8.32318902015686
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.607105731964111
# 9.227124214172363
# 256
# Results saved to runs/detect/predict2
# 250 labels saved to runs/detect/predict2/labels
# 6.525126934051514
# 8.758469820022583
# 256
# Results saved to runs/detect/predict2
# 251 labels saved to runs/detect/predict2/labels
# 7.217918872833252
# 9.458631038665771
# 256
# Results saved to runs/detect/predict2
# 251 labels saved to runs/detect/predict2/labels
# 6.004556655883789
# 8.162861824035645
# 256
# Results saved to runs/detect/predict2
# 251 labels saved to runs/detect/predict2/labels
# 6.768383741378784
# 9.013447999954224
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.291475296020508
# 8.526893377304077
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.701103925704956
# 9.313175439834595
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.211667776107788
# 8.626396417617798
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.968423366546631
# 8.176181077957153
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.5898144245147705
# 7.9453043937683105
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.438776731491089
# 7.591386556625366
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.3192291259765625
# 7.6937432289123535
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.799983739852905
# 8.333905220031738
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.204598903656006
# 7.401154518127441
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.61152720451355
# 8.966252088546753
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.5678441524505615
# 7.8161256313323975
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.437697172164917
# 8.560130596160889
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.3124165534973145
# 7.973637580871582
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 5.93213677406311
# 8.263900518417358
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.137981176376343
# 8.271837949752808
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.225572109222412
# 8.585373878479004
# 256
# Results saved to runs/detect/predict2
# 252 labels saved to runs/detect/predict2/labels
# 6.2383222579956055
# 8.51658821105957
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.116154193878174
# 7.211217403411865
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.292759895324707
# 7.635806560516357
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 6.300457239151001
# 8.400077819824219
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.332009315490723
# 7.486653089523315
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 6.176022529602051
# 8.314071416854858
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 6.381856203079224
# 8.523504257202148
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.672779083251953
# 7.777976751327515
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.558572053909302
# 7.902401447296143
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.753891229629517
# 7.829047679901123
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.441264629364014
# 7.874005079269409
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.202069282531738
# 7.254935026168823
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.181318044662476
# 7.456643581390381
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.33806848526001
# 7.428495168685913
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.2642576694488525
# 7.365240573883057
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.205596208572388
# 7.914091110229492
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.300894260406494
# 7.820817470550537
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.283260822296143
# 7.380450963973999
# 256
# Results saved to runs/detect/predict2
# 253 labels saved to runs/detect/predict2/labels
# 5.230479955673218
# 7.406140565872192
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 5.220465183258057
# 7.8053388595581055
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 5.344643831253052
# 7.471998929977417
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 6.962366342544556
# 9.089091062545776
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 5.32157826423645
# 7.494285345077515
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 5.164552450180054
# 7.4263756275177
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 5.000695466995239
# 7.327903985977173
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 6.003488540649414
# 8.486405611038208
# 256
# Results saved to runs/detect/predict2
# 254 labels saved to runs/detect/predict2/labels
# 5.402751445770264
# 7.93259596824646
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.29740047454834
# 7.630299806594849
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.210793733596802
# 7.298585414886475
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.09722900390625
# 7.364819288253784
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.2430739402771
# 7.472099542617798
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.160010814666748
# 7.342145204544067
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 4.952563047409058
# 7.159819602966309
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.8292858600616455
# 8.081007480621338
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.233968019485474
# 7.4644482135772705
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.175352334976196
# 7.345693588256836
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.2993483543396
# 7.470162630081177
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 6.194789409637451
# 8.353033065795898
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.304504632949829
# 7.62951135635376
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.174813985824585
# 7.567896366119385
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.291515350341797
# 7.864622116088867
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.303143262863159
# 7.6153717041015625
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.468311786651611
# 7.626912355422974
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.2934041023254395
# 7.753730535507202
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.1489293575286865
# 7.506171464920044
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.181363344192505
# 7.901988744735718
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.394576787948608
# 7.800073623657227
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.250712156295776
# 7.910876750946045
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.344924688339233
# 7.706042051315308
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.515055179595947
# 7.817225217819214
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.227968215942383
# 7.676294326782227
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.203723192214966
# 7.322095632553101
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.165185451507568
# 7.464243412017822
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.37420392036438
# 7.6475443840026855
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.045465707778931
# 7.287313461303711
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.389507532119751
# 7.935215950012207
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.251859426498413
# 7.84102988243103
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 4.890552759170532
# 7.286701679229736
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.344607353210449
# 7.45976185798645
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.132423400878906
# 7.418905973434448
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.68604588508606
# 8.27323317527771
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 4.984428644180298
# 7.19351053237915
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.39490270614624
# 7.8158392906188965
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.326195955276489
# 7.517103672027588
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.1146697998046875
# 7.2548229694366455
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.044851064682007
# 7.166505575180054
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.107649087905884
# 7.1853532791137695
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.020902633666992
# 7.582379102706909
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.174546480178833
# 7.3798828125
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.11594295501709
# 7.435006380081177
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.24431586265564
# 7.296892404556274
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.182323932647705
# 7.558817625045776
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.03630518913269
# 7.283467054367065
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.016941547393799
# 7.099870443344116
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.110190153121948
# 7.19642186164856
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 4.989220380783081
# 7.04284143447876
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.112607955932617
# 7.211181879043579
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 4.859529495239258
# 6.975987911224365
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.116388559341431
# 7.31552267074585
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.230273008346558
# 7.341709852218628
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.099836349487305
# 7.408904790878296
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.150925874710083
# 7.290048122406006
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.0323874950408936
# 7.621344804763794
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.2505717277526855
# 7.360701084136963
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.0685529708862305
# 7.212667942047119
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 6.720442056655884
# 8.823503017425537
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.348238945007324
# 7.4825356006622314
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.554659605026245
# 8.06691575050354
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 6.925895690917969
# 9.30096697807312
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 6.661333322525024
# 9.097050905227661
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.3516926765441895
# 7.722862005233765
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 6.747983932495117
# 8.836717367172241
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.0285797119140625
# 7.145819664001465
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.8623340129852295
# 8.110934734344482
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.753786325454712
# 8.283348798751831
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.33847188949585
# 7.518218994140625
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.054148435592651
# 7.295955181121826
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.2850182056427
# 7.476045846939087
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.231886148452759
# 7.447210073471069
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.045844316482544
# 7.2728657722473145
# 256
# Results saved to runs/detect/predict2
# 255 labels saved to runs/detect/predict2/labels
# 5.125479221343994
# 7.506122350692749
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.223288536071777
# 7.394824266433716
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.016327381134033
# 7.1412034034729
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.03589129447937
# 7.269822597503662
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.105028390884399
# 7.247562885284424
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.325450420379639
# 7.870209455490112
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.198084115982056
# 7.378892421722412
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.064530372619629
# 7.37212610244751
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.173884153366089
# 7.392880201339722
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.134779691696167
# 7.265069246292114
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.218724489212036
# 7.502815008163452
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.467430114746094
# 7.786160230636597
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.095926284790039
# 7.24881649017334
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.251211166381836
# 7.505171060562134
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.4843385219573975
# 7.662343263626099
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.413125276565552
# 7.57783055305481
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.125442028045654
# 7.277296781539917
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.907801151275635
# 8.062122583389282
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.202968597412109
# 8.432080745697021
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.553023815155029
# 7.749232530593872
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.335399627685547
# 8.735793113708496
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.397007703781128
# 8.83188271522522
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.248270511627197
# 7.5542120933532715
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.196850299835205
# 7.377750873565674
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.059633016586304
# 7.635925054550171
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.001438140869141
# 7.275755882263184
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.195892333984375
# 7.34903621673584
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.151544809341431
# 7.408859729766846
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.0033392906188965
# 7.39104151725769
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.058078289031982
# 7.659956693649292
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.386145830154419
# 7.545068979263306
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.1726953983306885
# 7.325589179992676
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.507473468780518
# 7.6532580852508545
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.131415128707886
# 7.827069282531738
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.262848377227783
# 7.437198638916016
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.405682563781738
# 8.561354875564575
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.538241863250732
# 8.693455457687378
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.096917629241943
# 8.221670866012573
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.385983228683472
# 7.708869934082031
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.2092039585113525
# 7.48442530632019
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.583913803100586
# 7.705949068069458
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.34870982170105
# 7.487692594528198
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.580853700637817
# 7.791407346725464
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 8.148122072219849
# 10.98152470588684
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.780414342880249
# 8.348692893981934
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.363527297973633
# 7.732335090637207
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.164210319519043
# 7.411437749862671
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.668209075927734
# 8.053134441375732
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.200691223144531
# 8.469686031341553
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.252424478530884
# 8.42659592628479
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.448785066604614
# 7.677557706832886
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.4282286167144775
# 8.694590330123901
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.869135618209839
# 8.198721170425415
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.226979970932007
# 8.46661114692688
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.4144017696380615
# 7.9425413608551025
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.709490060806274
# 7.852698087692261
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.807698488235474
# 8.250514507293701
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.002204895019531
# 8.33601689338684
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.427089214324951
# 7.81636643409729
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.297742128372192
# 7.654625654220581
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 7.892544507980347
# 10.324141502380371
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 23.525395393371582
# 25.925191164016724
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 7.04923152923584
# 9.25608515739441
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.752253770828247
# 8.221367359161377
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.3941051959991455
# 7.709253311157227
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.4493701457977295
# 7.628236293792725
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.958901643753052
# 8.285926580429077
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.275817632675171
# 7.637734651565552
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.535741329193115
# 8.026691913604736
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.46890115737915
# 8.060614585876465
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.849826335906982
# 8.038073539733887
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.350002288818359
# 7.469098329544067
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.245995998382568
# 7.449676275253296
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.115806579589844
# 7.279519557952881
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.751645565032959
# 7.895599365234375
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.382427453994751
# 7.505642652511597
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.407010078430176
# 7.55914306640625
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.262382984161377
# 7.423586368560791
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.458476543426514
# 7.771870136260986
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.30973744392395
# 7.439820289611816
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.126233100891113
# 7.579967975616455
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.09754204750061
# 7.521021127700806
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.181340456008911
# 7.5280115604400635
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.626660585403442
# 7.910891532897949
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.261569499969482
# 7.978748321533203
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.793575048446655
# 8.147130489349365
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.401302337646484
# 7.952640533447266
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.165528059005737
# 7.48078989982605
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.216103792190552
# 7.904866933822632
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.418936252593994
# 7.8709070682525635
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.207002401351929
# 7.453962564468384
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.157695770263672
# 7.639243125915527
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.65949559211731
# 8.873522281646729
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 7.300576210021973
# 9.592538595199585
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.137377500534058
# 7.379796504974365
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 6.21112322807312
# 8.434495449066162
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.155925512313843
# 7.466293811798096
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.921365976333618
# 8.038320541381836
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.158801794052124
# 7.611685276031494
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.3753440380096436
# 7.608717918395996
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.166160583496094
# 8.183825969696045
# 256
# Results saved to runs/detect/predict2
# 256 labels saved to runs/detect/predict2/labels
# 5.552485466003418
# 7.945832252502441
# 256
