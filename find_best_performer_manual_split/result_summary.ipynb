# %%
res_dict={}
res_dict["resnet18"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss": 0.00025225,
    "accuracy": 0.9728,
    "precision": 0.7124,
    "recall": 0.8880,  # Replace with the actual value for recall
    "f1": 0.7906
}
res_dict["efficientnet"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss":0.0025926,
    "accuracy": 0.9688,
    "precision": 0.6961,
    "recall": 0.8436,  # Replace with the actual value for recall
    "f1": 0.7628
}
res_dict["densenet"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss":0.0025926,
    "accuracy": 0.9709,
    "precision":0.6830,
    "recall": 0.8875,  # Replace with the actual value for recall
    "f1": 0.7719
}
res_dict["vit32_SELU"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss":0.1177,
    "accuracy": 0.9460,
    "precision":0.5098,
    "recall": 0.6624,  # Replace with the actual value for recall
    "f1": 0.5762
}
res_dict["efficientnet_pretrain"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss":0.00004,
    "accuracy": 0.9811,
    "precision":0.8301,
    "recall": 0.8991,  # Replace with the actual value for recall
    "f1": 0.8632
}
res_dict["resnet_pretrain"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss":0.00004,
    "accuracy": 0.9805,
    "precision":0.8301,
    "recall": 0.8912,  # Replace with the actual value for recall
    "f1": 0.8596
}
res_dict["alexnet_pretrain"] = {
    "train_data": 17000,
    "test_data": 8500,
    "train_loss":0.03517725,
    "accuracy": 0.9719,
    "precision":0.7026,
    "recall": 0.8830,  # Replace with the actual value for recall
    "f1": 0.7825
}

# %%
import pandas as pd
res_df = pd.DataFrame(res_dict).T.sort_values(by="f1")

res_df.style.format("{:.4f}").highlight_max(subset=["accuracy", "precision", "recall", "f1"], color="green").highlight_min(subset=["train_loss"], color="green")
# Out:
# <style type="text/css">
# #T_ee46a_row5_col2, #T_ee46a_row5_col4, #T_ee46a_row6_col2, #T_ee46a_row6_col3, #T_ee46a_row6_col4, #T_ee46a_row6_col5, #T_ee46a_row6_col6 {
#   background-color: green;
# }
# </style>
# <table id="T_ee46a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee46a_level0_col0" class="col_heading level0 col0" >train_data</th>
#       <th id="T_ee46a_level0_col1" class="col_heading level0 col1" >test_data</th>
#       <th id="T_ee46a_level0_col2" class="col_heading level0 col2" >train_loss</th>
#       <th id="T_ee46a_level0_col3" class="col_heading level0 col3" >accuracy</th>
#       <th id="T_ee46a_level0_col4" class="col_heading level0 col4" >precision</th>
#       <th id="T_ee46a_level0_col5" class="col_heading level0 col5" >recall</th>
#       <th id="T_ee46a_level0_col6" class="col_heading level0 col6" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee46a_level0_row0" class="row_heading level0 row0" >vit32_SELU</th>
#       <td id="T_ee46a_row0_col0" class="data row0 col0" >17000.0000</td>
#       <td id="T_ee46a_row0_col1" class="data row0 col1" >8500.0000</td>
#       <td id="T_ee46a_row0_col2" class="data row0 col2" >0.1177</td>
#       <td id="T_ee46a_row0_col3" class="data row0 col3" >0.9460</td>
#       <td id="T_ee46a_row0_col4" class="data row0 col4" >0.5098</td>
#       <td id="T_ee46a_row0_col5" class="data row0 col5" >0.6624</td>
#       <td id="T_ee46a_row0_col6" class="data row0 col6" >0.5762</td>
#     </tr>
#     <tr>
#       <th id="T_ee46a_level0_row1" class="row_heading level0 row1" >efficientnet</th>
#       <td id="T_ee46a_row1_col0" class="data row1 col0" >17000.0000</td>
#       <td id="T_ee46a_row1_col1" class="data row1 col1" >8500.0000</td>
#       <td id="T_ee46a_row1_col2" class="data row1 col2" >0.0026</td>
#       <td id="T_ee46a_row1_col3" class="data row1 col3" >0.9688</td>
#       <td id="T_ee46a_row1_col4" class="data row1 col4" >0.6961</td>
#       <td id="T_ee46a_row1_col5" class="data row1 col5" >0.8436</td>
#       <td id="T_ee46a_row1_col6" class="data row1 col6" >0.7628</td>
#     </tr>
#     <tr>
#       <th id="T_ee46a_level0_row2" class="row_heading level0 row2" >densenet</th>
#       <td id="T_ee46a_row2_col0" class="data row2 col0" >17000.0000</td>
#       <td id="T_ee46a_row2_col1" class="data row2 col1" >8500.0000</td>
#       <td id="T_ee46a_row2_col2" class="data row2 col2" >0.0026</td>
#       <td id="T_ee46a_row2_col3" class="data row2 col3" >0.9709</td>
#       <td id="T_ee46a_row2_col4" class="data row2 col4" >0.6830</td>
#       <td id="T_ee46a_row2_col5" class="data row2 col5" >0.8875</td>
#       <td id="T_ee46a_row2_col6" class="data row2 col6" >0.7719</td>
#     </tr>
#     <tr>
#       <th id="T_ee46a_level0_row3" class="row_heading level0 row3" >alexnet_pretrain</th>
#       <td id="T_ee46a_row3_col0" class="data row3 col0" >17000.0000</td>
#       <td id="T_ee46a_row3_col1" class="data row3 col1" >8500.0000</td>
#       <td id="T_ee46a_row3_col2" class="data row3 col2" >0.0352</td>
#       <td id="T_ee46a_row3_col3" class="data row3 col3" >0.9719</td>
#       <td id="T_ee46a_row3_col4" class="data row3 col4" >0.7026</td>
#       <td id="T_ee46a_row3_col5" class="data row3 col5" >0.8830</td>
#       <td id="T_ee46a_row3_col6" class="data row3 col6" >0.7825</td>
#     </tr>
#     <tr>
#       <th id="T_ee46a_level0_row4" class="row_heading level0 row4" >resnet18</th>
#       <td id="T_ee46a_row4_col0" class="data row4 col0" >17000.0000</td>
#       <td id="T_ee46a_row4_col1" class="data row4 col1" >8500.0000</td>
#       <td id="T_ee46a_row4_col2" class="data row4 col2" >0.0003</td>
#       <td id="T_ee46a_row4_col3" class="data row4 col3" >0.9728</td>
#       <td id="T_ee46a_row4_col4" class="data row4 col4" >0.7124</td>
#       <td id="T_ee46a_row4_col5" class="data row4 col5" >0.8880</td>
#       <td id="T_ee46a_row4_col6" class="data row4 col6" >0.7906</td>
#     </tr>
#     <tr>
#       <th id="T_ee46a_level0_row5" class="row_heading level0 row5" >resnet_pretrain</th>
#       <td id="T_ee46a_row5_col0" class="data row5 col0" >17000.0000</td>
#       <td id="T_ee46a_row5_col1" class="data row5 col1" >8500.0000</td>
#       <td id="T_ee46a_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_ee46a_row5_col3" class="data row5 col3" >0.9805</td>
#       <td id="T_ee46a_row5_col4" class="data row5 col4" >0.8301</td>
#       <td id="T_ee46a_row5_col5" class="data row5 col5" >0.8912</td>
#       <td id="T_ee46a_row5_col6" class="data row5 col6" >0.8596</td>
#     </tr>
#     <tr>
#       <th id="T_ee46a_level0_row6" class="row_heading level0 row6" >efficientnet_pretrain</th>
#       <td id="T_ee46a_row6_col0" class="data row6 col0" >17000.0000</td>
#       <td id="T_ee46a_row6_col1" class="data row6 col1" >8500.0000</td>
#       <td id="T_ee46a_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_ee46a_row6_col3" class="data row6 col3" >0.9811</td>
#       <td id="T_ee46a_row6_col4" class="data row6 col4" >0.8301</td>
#       <td id="T_ee46a_row6_col5" class="data row6 col5" >0.8991</td>
#       <td id="T_ee46a_row6_col6" class="data row6 col6" >0.8632</td>
#     </tr>
#   </tbody>
# </table>
