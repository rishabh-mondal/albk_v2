# %%
import pandas as pd

res_dict = {
    # "resnet18": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.00025225,
    #     "accuracy": 0.9728,
    #     "precision": 0.7124,
    #     "recall": 0.8880,
    #     "f1": 0.7906
    # },
    # "efficientnet": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.0025926,
    #     "accuracy": 0.9688,
    #     "precision": 0.6961,
    #     "recall": 0.8436,
    #     "f1": 0.7628
    # },
    # "densenet": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.0025926,
    #     "accuracy": 0.9709,
    #     "precision": 0.6830,
    #     "recall": 0.8875,
    #     "f1": 0.7719
    # },
    # "vit32_SELU": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.1177,
    #     "accuracy": 0.9460,
    #     "precision": 0.5098,
    #     "recall": 0.6624,
    #     "f1": 0.5762
    # },
    # "efficientnet_pretrain": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.00004,
    #     "accuracy": 0.9811,
    #     "precision": 0.8301,
    #     "recall": 0.8991,
    #     "f1": 0.8632
    # },
    # "resnet_pretrain": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.00004,
    #     "accuracy": 0.9805,
    #     "precision": 0.8301,
    #     "recall": 0.8912,
    #     "f1": 0.8596
    # },
    # "alexnet_pretrain": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.03517725,
    #     "accuracy": 0.9719,
    #     "precision": 0.7026,
    #     "recall": 0.8830,
    #     "f1": 0.7825
    # },
    # "v16_pretrain": {
    #     "train_data": 17000,
    #     "test_data": 8500,
    #     "train_loss": 0.0054,
    #     "accuracy": 0.9600,
    #     "precision": 0.6650,
    #     "recall": 0.7509,
    #     "f1": 0.7054
    # },
    "Efficientnet_pretrain": {
        "weights": "imagenet",
        "Fine Tune": "Bangladesh",
        "test_data": 'Bangladesh',
        "train_loss":  0.00134156,
        "accuracy": 0.9813,
        "precision": 0.8731,
        "recall": 0.8660,
        "f1": 0.8696,

    },
        "Resnet_pretrain": {
        "weights": "imagenet",
        "Fine Tune": "Bangladesh",
        "test_data": 'Bangladesh',    
        "train_loss": 0.00043,
        "accuracy": 0.9848,
        "precision": 0.9224,
        "recall": 0.8427,
        "f1": 0.8800
    },
        "Densenet_pretrain": {
        "train_data": "CVD",
        "test_data": 'CVD',
        "train_loss": 0.00002230,
        "accuracy": 0.9857,
        "precision": 0.8686,
        "recall": 0.9128,
        "f1": 0.8900
    },
        "ViT16_pretrain": {
        "train_data": "CVD",
        "test_data": 'CVD',
        "train_loss": 0.0016,
        "accuracy": 0.9740,
        "precision": 0.7476,
        "recall": 0.8431,
        "f1": 0.7925
    },        
    "Efficientnet_(Pred)": {
        "weights": "imagenet",
        "Fine Tune": "Bangladesh",
        "test_data": 'Delhi',
        "train_loss":  0.00103105,
        "accuracy": 0.9440,
        "precision": 0.9097,
        "recall": 0.5125,
        "f1": 0.6556,
    },
    "Resnet_(Pred)": {
        "weights": "imagenet",
        "Fine Tune": "Bangladesh",
        "test_data": 'Delhi',
        "train_loss": 0.00000006,
        "accuracy": 0.9343,
        "precision": 0.9549,
        "recall": 0.3858,
        "f1": 0.5496,
    },
    "Densenet_(Pred)": {
        "weights": "imagenet",
        "Fine Tune": "Bangladesh",
        "test_data": 'Delhi',
        "train_loss": 0.00099948,
        "accuracy": 0.9275,
        "precision": 0.9245,
        "recall": 0.3292,
        "f1": 0.4855,

    },
    "ViT16_(Pred)": {
        "weights": "imagenet",
        "Fine Tune": "Bangladesh",
        "test_data": 'Delhi',
        "train_loss": 0.00299704,
        "accuracy": 0.9052,
        "precision": 0.7840,
        "recall": 0.1219,
        "f1": 0.2110,

    },

}


res_df = pd.DataFrame(res_dict).T

# Convert "f1" column to numeric before sorting
res_df["f1"] = pd.to_numeric(res_df["f1"], errors="coerce")

# Selectively format only numeric columns
numeric_cols = ["train_loss", "accuracy", "precision", "recall", "f1"]
res_df[numeric_cols] = res_df[numeric_cols].applymap("{:.5f}".format)

# Sort DataFrame by "f1"
res_df = res_df.sort_values(by="f1")

result_summery = (
    res_df.style
    .highlight_max(subset=["accuracy", "precision", "recall", "f1"], color="green")
    .highlight_min(subset=["accuracy", "precision", "recall", "f1"], color="red")

)

# Display the styled DataFrame
result_summery
# Out:
# /tmp/ipykernel_1949259/132389854.py:168: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   res_df[numeric_cols] = res_df[numeric_cols].applymap("{:.5f}".format)
# <style type="text/css">
# #T_ddb9a_row0_col4, #T_ddb9a_row0_col6, #T_ddb9a_row0_col7, #T_ddb9a_row4_col5 {
#   background-color: red;
# }
# #T_ddb9a_row2_col5, #T_ddb9a_row7_col4, #T_ddb9a_row7_col6, #T_ddb9a_row7_col7 {
#   background-color: green;
# }
# </style>
# <table id="T_ddb9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddb9a_level0_col0" class="col_heading level0 col0" >weights</th>
#       <th id="T_ddb9a_level0_col1" class="col_heading level0 col1" >Fine Tune</th>
#       <th id="T_ddb9a_level0_col2" class="col_heading level0 col2" >test_data</th>
#       <th id="T_ddb9a_level0_col3" class="col_heading level0 col3" >train_loss</th>
#       <th id="T_ddb9a_level0_col4" class="col_heading level0 col4" >accuracy</th>
#       <th id="T_ddb9a_level0_col5" class="col_heading level0 col5" >precision</th>
#       <th id="T_ddb9a_level0_col6" class="col_heading level0 col6" >recall</th>
#       <th id="T_ddb9a_level0_col7" class="col_heading level0 col7" >f1</th>
#       <th id="T_ddb9a_level0_col8" class="col_heading level0 col8" >train_data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddb9a_level0_row0" class="row_heading level0 row0" >ViT16_(Pred)</th>
#       <td id="T_ddb9a_row0_col0" class="data row0 col0" >imagenet</td>
#       <td id="T_ddb9a_row0_col1" class="data row0 col1" >Bangladesh</td>
#       <td id="T_ddb9a_row0_col2" class="data row0 col2" >Delhi</td>
#       <td id="T_ddb9a_row0_col3" class="data row0 col3" >0.00300</td>
#       <td id="T_ddb9a_row0_col4" class="data row0 col4" >0.90520</td>
#       <td id="T_ddb9a_row0_col5" class="data row0 col5" >0.78400</td>
#       <td id="T_ddb9a_row0_col6" class="data row0 col6" >0.12190</td>
#       <td id="T_ddb9a_row0_col7" class="data row0 col7" >0.21100</td>
#       <td id="T_ddb9a_row0_col8" class="data row0 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row1" class="row_heading level0 row1" >Densenet_(Pred)</th>
#       <td id="T_ddb9a_row1_col0" class="data row1 col0" >imagenet</td>
#       <td id="T_ddb9a_row1_col1" class="data row1 col1" >Bangladesh</td>
#       <td id="T_ddb9a_row1_col2" class="data row1 col2" >Delhi</td>
#       <td id="T_ddb9a_row1_col3" class="data row1 col3" >0.00100</td>
#       <td id="T_ddb9a_row1_col4" class="data row1 col4" >0.92750</td>
#       <td id="T_ddb9a_row1_col5" class="data row1 col5" >0.92450</td>
#       <td id="T_ddb9a_row1_col6" class="data row1 col6" >0.32920</td>
#       <td id="T_ddb9a_row1_col7" class="data row1 col7" >0.48550</td>
#       <td id="T_ddb9a_row1_col8" class="data row1 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row2" class="row_heading level0 row2" >Resnet_(Pred)</th>
#       <td id="T_ddb9a_row2_col0" class="data row2 col0" >imagenet</td>
#       <td id="T_ddb9a_row2_col1" class="data row2 col1" >Bangladesh</td>
#       <td id="T_ddb9a_row2_col2" class="data row2 col2" >Delhi</td>
#       <td id="T_ddb9a_row2_col3" class="data row2 col3" >0.00000</td>
#       <td id="T_ddb9a_row2_col4" class="data row2 col4" >0.93430</td>
#       <td id="T_ddb9a_row2_col5" class="data row2 col5" >0.95490</td>
#       <td id="T_ddb9a_row2_col6" class="data row2 col6" >0.38580</td>
#       <td id="T_ddb9a_row2_col7" class="data row2 col7" >0.54960</td>
#       <td id="T_ddb9a_row2_col8" class="data row2 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row3" class="row_heading level0 row3" >Efficientnet_(Pred)</th>
#       <td id="T_ddb9a_row3_col0" class="data row3 col0" >imagenet</td>
#       <td id="T_ddb9a_row3_col1" class="data row3 col1" >Bangladesh</td>
#       <td id="T_ddb9a_row3_col2" class="data row3 col2" >Delhi</td>
#       <td id="T_ddb9a_row3_col3" class="data row3 col3" >0.00103</td>
#       <td id="T_ddb9a_row3_col4" class="data row3 col4" >0.94400</td>
#       <td id="T_ddb9a_row3_col5" class="data row3 col5" >0.90970</td>
#       <td id="T_ddb9a_row3_col6" class="data row3 col6" >0.51250</td>
#       <td id="T_ddb9a_row3_col7" class="data row3 col7" >0.65560</td>
#       <td id="T_ddb9a_row3_col8" class="data row3 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row4" class="row_heading level0 row4" >ViT16_pretrain</th>
#       <td id="T_ddb9a_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_ddb9a_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_ddb9a_row4_col2" class="data row4 col2" >CVD</td>
#       <td id="T_ddb9a_row4_col3" class="data row4 col3" >0.00160</td>
#       <td id="T_ddb9a_row4_col4" class="data row4 col4" >0.97400</td>
#       <td id="T_ddb9a_row4_col5" class="data row4 col5" >0.74760</td>
#       <td id="T_ddb9a_row4_col6" class="data row4 col6" >0.84310</td>
#       <td id="T_ddb9a_row4_col7" class="data row4 col7" >0.79250</td>
#       <td id="T_ddb9a_row4_col8" class="data row4 col8" >CVD</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row5" class="row_heading level0 row5" >Efficientnet_pretrain</th>
#       <td id="T_ddb9a_row5_col0" class="data row5 col0" >imagenet</td>
#       <td id="T_ddb9a_row5_col1" class="data row5 col1" >Bangladesh</td>
#       <td id="T_ddb9a_row5_col2" class="data row5 col2" >Bangladesh</td>
#       <td id="T_ddb9a_row5_col3" class="data row5 col3" >0.00134</td>
#       <td id="T_ddb9a_row5_col4" class="data row5 col4" >0.98130</td>
#       <td id="T_ddb9a_row5_col5" class="data row5 col5" >0.87310</td>
#       <td id="T_ddb9a_row5_col6" class="data row5 col6" >0.86600</td>
#       <td id="T_ddb9a_row5_col7" class="data row5 col7" >0.86960</td>
#       <td id="T_ddb9a_row5_col8" class="data row5 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row6" class="row_heading level0 row6" >Resnet_pretrain</th>
#       <td id="T_ddb9a_row6_col0" class="data row6 col0" >imagenet</td>
#       <td id="T_ddb9a_row6_col1" class="data row6 col1" >Bangladesh</td>
#       <td id="T_ddb9a_row6_col2" class="data row6 col2" >Bangladesh</td>
#       <td id="T_ddb9a_row6_col3" class="data row6 col3" >0.00043</td>
#       <td id="T_ddb9a_row6_col4" class="data row6 col4" >0.98480</td>
#       <td id="T_ddb9a_row6_col5" class="data row6 col5" >0.92240</td>
#       <td id="T_ddb9a_row6_col6" class="data row6 col6" >0.84270</td>
#       <td id="T_ddb9a_row6_col7" class="data row6 col7" >0.88000</td>
#       <td id="T_ddb9a_row6_col8" class="data row6 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ddb9a_level0_row7" class="row_heading level0 row7" >Densenet_pretrain</th>
#       <td id="T_ddb9a_row7_col0" class="data row7 col0" >nan</td>
#       <td id="T_ddb9a_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_ddb9a_row7_col2" class="data row7 col2" >CVD</td>
#       <td id="T_ddb9a_row7_col3" class="data row7 col3" >0.00002</td>
#       <td id="T_ddb9a_row7_col4" class="data row7 col4" >0.98570</td>
#       <td id="T_ddb9a_row7_col5" class="data row7 col5" >0.86860</td>
#       <td id="T_ddb9a_row7_col6" class="data row7 col6" >0.91280</td>
#       <td id="T_ddb9a_row7_col7" class="data row7 col7" >0.89000</td>
#       <td id="T_ddb9a_row7_col8" class="data row7 col8" >CVD</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd

res_dict = {

    "efficientnet_pretrain_B": {
    "train_data": "Bangladesh",
    "train_data_size": 19125,
    "class 1": 1273,
    "class 0": 17852,
    "test_data": 'Bangladesh',
    "test_data": 6375,
    "class 1": 425,
    "class 0": 5950,
    "ZicZac and FCK": "1285+412",
    "accuracy": 0.9871,
    "precision": 0.9130,
    "recall": 0.8915,
    "f1": 0.8923
    },


    "efficientnet_pretrain_D": {
    "train_data": "Delhi",
    "train_data_size": 7518,
    "class 1": 781,
    "class 0": 6737,
    "test_data": 'Delhi',
    "test_data": 2506,
    "class 1": 260,
    "class 0": 2246,
    "ZicZac and FCK": "1002+40",
    "accuracy": 0.9784,
    "precision": 0.8936,
    "recall": 0.9002,
    "f1": 0.8963
    },

    "efficientnet_pretrain_BD": {
    "train_data": "Bangladesh",
    "train_data_size": 25550,
    "class 1": 1698,
    "class 0": 23852,
    "test_data": 'Delhi',
    "test_data": 10024,
    "class 1": 1040,
    "class 0": 8984,
    # "ZicZac and FCK": ,
    "accuracy": 0.9440,
    "precision": 0.9097,
    "recall": 0.5125,
    "f1": 0.6556
    },
         


}


res_df = pd.DataFrame(res_dict).T

# Convert "f1" column to numeric before sorting
res_df["f1"] = pd.to_numeric(res_df["f1"], errors="coerce")

# Selectively format only numeric columns
numeric_cols = [ "accuracy", "precision", "recall", "f1"]
res_df[numeric_cols] = res_df[numeric_cols].applymap("{:.5f}".format)

# Sort DataFrame by "f1"
res_df = res_df.sort_values(by="f1")

result_summery = (
    res_df.style
    .highlight_max(subset=["accuracy", "precision", "recall", "f1"], color="green")
    .highlight_min(subset=["accuracy", "precision", "recall", "f1"], color="red")

)

# Display the styled DataFrame
result_summery
# Out:
# /tmp/ipykernel_3170232/3086507809.py:66: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   res_df[numeric_cols] = res_df[numeric_cols].applymap("{:.5f}".format)
# <style type="text/css">
# #T_8549b_row0_col6, #T_8549b_row0_col8, #T_8549b_row0_col9, #T_8549b_row2_col7 {
#   background-color: red;
# }
# #T_8549b_row1_col6, #T_8549b_row1_col7, #T_8549b_row2_col8, #T_8549b_row2_col9 {
#   background-color: green;
# }
# </style>
# <table id="T_8549b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8549b_level0_col0" class="col_heading level0 col0" >train_data</th>
#       <th id="T_8549b_level0_col1" class="col_heading level0 col1" >train_data_size</th>
#       <th id="T_8549b_level0_col2" class="col_heading level0 col2" >class 1</th>
#       <th id="T_8549b_level0_col3" class="col_heading level0 col3" >class 0</th>
#       <th id="T_8549b_level0_col4" class="col_heading level0 col4" >test_data</th>
#       <th id="T_8549b_level0_col5" class="col_heading level0 col5" >ZicZac and FCK</th>
#       <th id="T_8549b_level0_col6" class="col_heading level0 col6" >accuracy</th>
#       <th id="T_8549b_level0_col7" class="col_heading level0 col7" >precision</th>
#       <th id="T_8549b_level0_col8" class="col_heading level0 col8" >recall</th>
#       <th id="T_8549b_level0_col9" class="col_heading level0 col9" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8549b_level0_row0" class="row_heading level0 row0" >efficientnet_pretrain_BD</th>
#       <td id="T_8549b_row0_col0" class="data row0 col0" >Bangladesh</td>
#       <td id="T_8549b_row0_col1" class="data row0 col1" >25550</td>
#       <td id="T_8549b_row0_col2" class="data row0 col2" >1040</td>
#       <td id="T_8549b_row0_col3" class="data row0 col3" >8984</td>
#       <td id="T_8549b_row0_col4" class="data row0 col4" >10024</td>
#       <td id="T_8549b_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_8549b_row0_col6" class="data row0 col6" >0.94400</td>
#       <td id="T_8549b_row0_col7" class="data row0 col7" >0.90970</td>
#       <td id="T_8549b_row0_col8" class="data row0 col8" >0.51250</td>
#       <td id="T_8549b_row0_col9" class="data row0 col9" >0.65560</td>
#     </tr>
#     <tr>
#       <th id="T_8549b_level0_row1" class="row_heading level0 row1" >efficientnet_pretrain_B</th>
#       <td id="T_8549b_row1_col0" class="data row1 col0" >Bangladesh</td>
#       <td id="T_8549b_row1_col1" class="data row1 col1" >19125</td>
#       <td id="T_8549b_row1_col2" class="data row1 col2" >425</td>
#       <td id="T_8549b_row1_col3" class="data row1 col3" >5950</td>
#       <td id="T_8549b_row1_col4" class="data row1 col4" >6375</td>
#       <td id="T_8549b_row1_col5" class="data row1 col5" >1285+412</td>
#       <td id="T_8549b_row1_col6" class="data row1 col6" >0.98710</td>
#       <td id="T_8549b_row1_col7" class="data row1 col7" >0.91300</td>
#       <td id="T_8549b_row1_col8" class="data row1 col8" >0.89150</td>
#       <td id="T_8549b_row1_col9" class="data row1 col9" >0.89230</td>
#     </tr>
#     <tr>
#       <th id="T_8549b_level0_row2" class="row_heading level0 row2" >efficientnet_pretrain_D</th>
#       <td id="T_8549b_row2_col0" class="data row2 col0" >Delhi</td>
#       <td id="T_8549b_row2_col1" class="data row2 col1" >7518</td>
#       <td id="T_8549b_row2_col2" class="data row2 col2" >260</td>
#       <td id="T_8549b_row2_col3" class="data row2 col3" >2246</td>
#       <td id="T_8549b_row2_col4" class="data row2 col4" >2506</td>
#       <td id="T_8549b_row2_col5" class="data row2 col5" >1002+40</td>
#       <td id="T_8549b_row2_col6" class="data row2 col6" >0.97840</td>
#       <td id="T_8549b_row2_col7" class="data row2 col7" >0.89360</td>
#       <td id="T_8549b_row2_col8" class="data row2 col8" >0.90020</td>
#       <td id="T_8549b_row2_col9" class="data row2 col9" >0.89630</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd

res_dict = {
    "efficientnet_pretrain_B": {
        "train_data": "Bangladesh",
        "train_data_size": 19125,
        "class 1": 1273,
        "class 0": 17852,
        "test_data": 'Bangladesh',
        "test_data_size": 6375,
        "class 1_test": 425,
        "class 0_test": 5950,
        "ZicZac and FCK": "1285+412",
        "accuracy": 0.9871,
        "precision": 0.9130,
        "recall": 0.8915,
        "f1": 0.8923
    },
    "efficientnet_pretrain_D": {
        "train_data": "Delhi",
        "train_data_size": 7518,
        "class 1": 781,
        "class 0": 6737,
        "test_data": 'Delhi',
        "test_data_size": 2506,
        "class 1_test": 260,
        "class 0_test": 2246,
        "ZicZac and FCK": "1002+40",
        "accuracy": 0.9784,
        "precision": 0.8936,
        "recall": 0.9002,
        "f1": 0.8963
    },
    "efficientnet_pretrain_BD": {
        "train_data": "Bangladesh",
        "train_data_size": 25550,
        "class 1": 1698,
        "class 0": 23852,
        "test_data": 'Delhi',
        "test_data_size": 10024,
        "class 1_test": 1040,
        "class 0_test": 8984,
        # "ZicZac and FCK": "ADD_CORRECT_VALUE_HERE",
        "accuracy": 0.9440,
        "precision": 0.9097,
        "recall": 0.5125,
        "f1": 0.6556
    },
}

res_df = pd.DataFrame(res_dict).T

# Convert "f1" column to numeric before sorting
res_df["f1"] = pd.to_numeric(res_df["f1"], errors="coerce")

# Selectively format only numeric columns
numeric_cols = ["accuracy", "precision", "recall", "f1"]
res_df[numeric_cols] = res_df[numeric_cols].applymap("{:.5f}".format)

# Sort DataFrame by "f1"
res_df = res_df.sort_values(by="f1")

result_summary = (
    res_df.style
    .highlight_max(subset=["accuracy", "precision", "recall", "f1"], color="green")
    .highlight_min(subset=["accuracy", "precision", "recall", "f1"], color="red")
)

# Display the styled DataFrame
result_summary
# Out:
# /tmp/ipykernel_3170232/4026405725.py:58: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   res_df[numeric_cols] = res_df[numeric_cols].applymap("{:.5f}".format)
# <style type="text/css">
# #T_549bc_row0_col9, #T_549bc_row0_col11, #T_549bc_row0_col12, #T_549bc_row2_col10 {
#   background-color: red;
# }
# #T_549bc_row1_col9, #T_549bc_row1_col10, #T_549bc_row2_col11, #T_549bc_row2_col12 {
#   background-color: green;
# }
# </style>
# <table id="T_549bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_549bc_level0_col0" class="col_heading level0 col0" >train_data</th>
#       <th id="T_549bc_level0_col1" class="col_heading level0 col1" >train_data_size</th>
#       <th id="T_549bc_level0_col2" class="col_heading level0 col2" >class 1</th>
#       <th id="T_549bc_level0_col3" class="col_heading level0 col3" >class 0</th>
#       <th id="T_549bc_level0_col4" class="col_heading level0 col4" >test_data</th>
#       <th id="T_549bc_level0_col5" class="col_heading level0 col5" >test_data_size</th>
#       <th id="T_549bc_level0_col6" class="col_heading level0 col6" >class 1_test</th>
#       <th id="T_549bc_level0_col7" class="col_heading level0 col7" >class 0_test</th>
#       <th id="T_549bc_level0_col8" class="col_heading level0 col8" >ZicZac and FCK</th>
#       <th id="T_549bc_level0_col9" class="col_heading level0 col9" >accuracy</th>
#       <th id="T_549bc_level0_col10" class="col_heading level0 col10" >precision</th>
#       <th id="T_549bc_level0_col11" class="col_heading level0 col11" >recall</th>
#       <th id="T_549bc_level0_col12" class="col_heading level0 col12" >f1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_549bc_level0_row0" class="row_heading level0 row0" >efficientnet_pretrain_BD</th>
#       <td id="T_549bc_row0_col0" class="data row0 col0" >Bangladesh</td>
#       <td id="T_549bc_row0_col1" class="data row0 col1" >25550</td>
#       <td id="T_549bc_row0_col2" class="data row0 col2" >1698</td>
#       <td id="T_549bc_row0_col3" class="data row0 col3" >23852</td>
#       <td id="T_549bc_row0_col4" class="data row0 col4" >Delhi</td>
#       <td id="T_549bc_row0_col5" class="data row0 col5" >10024</td>
#       <td id="T_549bc_row0_col6" class="data row0 col6" >1040</td>
#       <td id="T_549bc_row0_col7" class="data row0 col7" >8984</td>
#       <td id="T_549bc_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_549bc_row0_col9" class="data row0 col9" >0.94400</td>
#       <td id="T_549bc_row0_col10" class="data row0 col10" >0.90970</td>
#       <td id="T_549bc_row0_col11" class="data row0 col11" >0.51250</td>
#       <td id="T_549bc_row0_col12" class="data row0 col12" >0.65560</td>
#     </tr>
#     <tr>
#       <th id="T_549bc_level0_row1" class="row_heading level0 row1" >efficientnet_pretrain_B</th>
#       <td id="T_549bc_row1_col0" class="data row1 col0" >Bangladesh</td>
#       <td id="T_549bc_row1_col1" class="data row1 col1" >19125</td>
#       <td id="T_549bc_row1_col2" class="data row1 col2" >1273</td>
#       <td id="T_549bc_row1_col3" class="data row1 col3" >17852</td>
#       <td id="T_549bc_row1_col4" class="data row1 col4" >Bangladesh</td>
#       <td id="T_549bc_row1_col5" class="data row1 col5" >6375</td>
#       <td id="T_549bc_row1_col6" class="data row1 col6" >425</td>
#       <td id="T_549bc_row1_col7" class="data row1 col7" >5950</td>
#       <td id="T_549bc_row1_col8" class="data row1 col8" >1285+412</td>
#       <td id="T_549bc_row1_col9" class="data row1 col9" >0.98710</td>
#       <td id="T_549bc_row1_col10" class="data row1 col10" >0.91300</td>
#       <td id="T_549bc_row1_col11" class="data row1 col11" >0.89150</td>
#       <td id="T_549bc_row1_col12" class="data row1 col12" >0.89230</td>
#     </tr>
#     <tr>
#       <th id="T_549bc_level0_row2" class="row_heading level0 row2" >efficientnet_pretrain_D</th>
#       <td id="T_549bc_row2_col0" class="data row2 col0" >Delhi</td>
#       <td id="T_549bc_row2_col1" class="data row2 col1" >7518</td>
#       <td id="T_549bc_row2_col2" class="data row2 col2" >781</td>
#       <td id="T_549bc_row2_col3" class="data row2 col3" >6737</td>
#       <td id="T_549bc_row2_col4" class="data row2 col4" >Delhi</td>
#       <td id="T_549bc_row2_col5" class="data row2 col5" >2506</td>
#       <td id="T_549bc_row2_col6" class="data row2 col6" >260</td>
#       <td id="T_549bc_row2_col7" class="data row2 col7" >2246</td>
#       <td id="T_549bc_row2_col8" class="data row2 col8" >1002+40</td>
#       <td id="T_549bc_row2_col9" class="data row2 col9" >0.97840</td>
#       <td id="T_549bc_row2_col10" class="data row2 col10" >0.89360</td>
#       <td id="T_549bc_row2_col11" class="data row2 col11" >0.90020</td>
#       <td id="T_549bc_row2_col12" class="data row2 col12" >0.89630</td>
#     </tr>
#   </tbody>
# </table>
